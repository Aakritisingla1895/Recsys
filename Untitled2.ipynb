# %%
import numpy as np # linear algebra
import pandas as pd
from sklearn.metrics.pairwise import cosine_similarity
ratings=pd.read_csv('ai_cite.csv')
ratings.head(15)
# Out:
#     user_id  author_id  cited   timestamp
# 0         1         31    101  1260759144
# 1         1         10     38  1260759179
# 2         1         17     82  1260759182
# 3         1         39     49  1260759185
# 4         1         47     49  1260759205
# 5         1         50     82  1260759151
# 6         1         52    104  1260759187
# 7         1         62     43  1260759148
# 8         1        110    129  1260759125
# 9         1        144     23  1260759131
# 10        1        150     65  1260759135
# 11        1        153     83  1260759203
# 12        1        161     20  1260759191
# 13        1        165     28  1260759139
# 14        1        168     64  1260759194

# %%
articles=pd.read_csv('ai_journal_articles_clean.csv')
articles.head(15)
# Out:
#     affliations                                       article_name  \
# 0           NaN             Solving the Torpedo Scheduling Problem
# 1           NaN  Xeggora: Exploiting Immune-to-Evidence Symmetr...
# 2           NaN  Recognizing Top-Monotonic Preference Profiles ...
# 3           NaN  Rationalisation of Profiles of Abstract Argume...
# 4           NaN  Probabilistic Description Logics for Subjectiv...
# 5           NaN             Kernel Contraction and Base Dependence
# 6           NaN  The Computational Complexity of Structure-Base...
# 7           NaN  Dynamic Repositioning to Reduce Lost Demand in...
# 8           NaN  Using Collective Behavior of Coupled Oscillato...
# 9           NaN  Conditional Simple Temporal Networks with Unce...
# 10          NaN  Qualitative Spatial Logics for Buffered Geomet...
# 11          NaN  The IBaCoP Planning System: Instance-Based Con...
# 12          NaN                   Datalog+- Ontology Consolidation
# ...

# %%
article_citations = pd.merge(articles, ratings)
article_citations.head(15)
# Out:
#     affliations                                       article_name  \
# 0           NaN             Solving the Torpedo Scheduling Problem
# 1           NaN  Probabilistic Inference Techniques for Scalabl...
# 2           NaN  Two Aspects of Relevance in Structured Argumen...
# 3           NaN  Xeggora: Exploiting Immune-to-Evidence Symmetr...
# 4           NaN  A Hidden Markov Model-Based Acoustic Cicada De...
# 5           NaN  Constraining Information Sharing to Improve Co...
# 6           NaN                Clause Elimination for SAT and QSAT
# 7           NaN  Exploiting Causality for Selective Belief Filt...
# 8           NaN  Association Discovery and Diagnosis of Alzheim...
# 9           NaN  Recognizing Top-Monotonic Preference Profiles ...
# 10          NaN  The Ceteris Paribus Structure of Logics of Gam...
# 11          NaN  Budgeted Optimization with Constrained Experim...
# 12          NaN  Rationalisation of Profiles of Abstract Argume...
# ...

# %%
ratings_matrix = ratings.pivot_table(columns=['author_id'],values='cited').reset_index(drop=True)
ratings_matrix.fillna( 0, inplace = True )
ratings_matrix.head(15)
# Out:
# author_id  10   17   31   39   47   50   52   62   110  144 ...   225  235  \
# 0           38   82  101   49   49   82  104   43  129   23 ...    33   43
#
# author_id  248  253  261  265  266  272  273  292
# 0          102   29   38   29   38   33   39   38
#
# [1 rows x 30 columns]

# %%
article_similarity=cosine_similarity(ratings_matrix)
np.fill_diagonal( article_similarity, 0 ) 
article_similarity
# Out:
# array([[0.]])

# %%
ratings_matrix = pd.DataFrame( article_similarity )
ratings_matrix.head(15)
# Out:
#      0
# 0  0.0

# %%
try:
    
    user_inp="artificial intellience"
    inp=articles[articles['title']==user_inp].index.tolist()
    inp=inp[0]
    
    articles['similarity'] = ratings_matrix.iloc[inp]
    articles.head(5)
    
except:
    print("Sorry, the article is not in the database!")
    
print("Recommended articles based on your choice of ",user_inp ,": \n", articles.sort_values( ["similarity"], ascending = False )[1:10])
# Out:
# Sorry, the article is not in the database!
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-21-d82b7b3f57a8> in <module>
#      11     print("Sorry, the article is not in the database!")
#      12
# ---> 13 print("Recommended articles based on your choice of ",user_inp ,": \n", articles.sort_values( ["similarity"], ascending = False )[1:10])
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in sort_values(self, by, axis, ascending, inplace, kind, na_position)
#    4419             by = by[0]
#    4420             k = self._get_label_or_level_values(by, axis=axis,
# -> 4421                                                 stacklevel=stacklevel)
#    4422
#    4423             if isinstance(ascending, (tuple, list)):
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in _get_label_or_level_values(self, key, axis, stacklevel)
# ...
