# %%
import pandas as pd 
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('ai_test.csv', sep='\t', names=['author_name','affliations','article_title','doi'])

# %%
df.head()
# Out:
#                                          author_name  affliations  \
# 0  author_name,affliations,article_title,doi,volu...          NaN
# 1  Martin Josef Geiger,"University of the Federal...          NaN
# 2  Lucas Kletzander,Null,Solving the Torpedo Sche...          NaN
# 3  Nysret Musliu,"Priv. Dozent and Senior Scienti...          NaN
# 4  Mohammad Mahdi Amirian,"Department of Electric...          NaN
#
#    article_title  doi
# 0            NaN  NaN
# 1            NaN  NaN
# 2            NaN  NaN
# 3            NaN  NaN
# 4            NaN  NaN

# %%
article_titles = pd.read_csv('rate.csv')

# %%
article_titles.head(15)
# Out:
#     userId  articleId  rating   timestamp
# 0        1         31     2.5  1260759144
# 1        1       1029     3.0  1260759179
# 2        1       1061     3.0  1260759182
# 3        1       1129     2.0  1260759185
# 4        1       1172     4.0  1260759205
# 5        1       1263     2.0  1260759151
# 6        1       1287     2.0  1260759187
# 7        1       1293     2.0  1260759148
# 8        1       1339     3.5  1260759125
# 9        1       1343     2.0  1260759131
# 10       1       1371     2.5  1260759135
# 11       1       1405     1.0  1260759203
# 12       1       1953     4.0  1260759191
# 13       1       2105     4.0  1260759139
# 14       1       2150     3.0  1260759194

# %%
merge = pd.read_csv('merge.csv')
merge.head(15)
# Out:
#                  author_name  \
# 0        Martin Josef Geiger
# 1           Lucas Kletzander
# 2              Nysret Musliu
# 3     Mohammad Mahdi Amirian
# 4        Saeed Shiry Ghidary
# 5          Krzysztof Magiera
# 6          Piotr Faliszewski
# 7          Stâ€šphane Airiau
# 8               Elise Bonzon
# 9               Ulle Endriss
# 10            Nicolas Maudet
# 11             Julien Rossit
# 12  Victor Gutierrez-Basulto
# 13       Jean Christoph Jung
# 14              Carsten Lutz
#
#                                           affliations  \
# 0   University of the Federal Armed Forces Hamburg...
# 1                                                Null
# 2   Priv. Dozent and Senior Scientist, Vienna Univ...
# 3   Department of Electrical and Computer Engineer...
# 4    Amirkabir University of Technology, Tehran, Iran
# 5                                                Null
# 6   AGH University of Science and Technology, Krak...
# ...

# %%
ratings_matrix = ratings.pivot_table(index=['movieId'],columns=['userId'],values='rating').reset_index(drop=True)
ratings_matrix.fillna( 0, inplace = True )
ratings_matrix.head(15)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-29-d28544e9b0d0> in <module>
# ----> 1 ratings_matrix = df.pivot_table(index=['author_name'],columns=['userId']).reset_index(drop=True)
#       2 ratings_matrix.fillna( 0, inplace = True )
#       3 ratings_matrix.head(15)
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in pivot_table(self, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name)
#    5301                            aggfunc=aggfunc, fill_value=fill_value,
#    5302                            margins=margins, dropna=dropna,
# -> 5303                            margins_name=margins_name)
#    5304
#    5305     def stack(self, level=-1, dropna=True):
#
# ~\Anaconda3\lib\site-packages\pandas\core\reshape\pivot.py in pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name)
# ...
