# %%
import pandas as pd

# %%
data = pd.read_csv("ai_test.csv") 
data
# Out:
#                   author_name  \
# 0         Martin Josef Geiger
# 1            Lucas Kletzander
# 2               Nysret Musliu
# 3      Mohammad Mahdi Amirian
# 4         Saeed Shiry Ghidary
# 5           Krzysztof Magiera
# 6           Piotr Faliszewski
# 7             St‚phane Airiau
# 8                Elise Bonzon
# 9                Ulle Endriss
# 10             Nicolas Maudet
# 11              Julien Rossit
# 12   Victor Gutierrez-Basulto
# 13        Jean Christoph Jung
# 14               Carsten Lutz
# 15              Lutz Schr”der
# 16             Mehrdad Oveisi
# 17         James P. Delgrande
# 18   Francis Jeffry Pelletier
# 19              Fred Popowich
# 20        Gadi Aleksandrowicz
# 21              Hana Chockler
# 22          Joseph Y. Halpern
# 23            Alexander Ivrii
# 24              Supriyo Ghosh
# 25        Pradeep Varakantham
# 26          Yossiri Adulyasak
# 27            Patrick Jaillet
# 28             Allan R. Leite
# 29         Fabricio Enembreck
# ..                        ...
# 210                  D. Xiong
# 211                    Q. Liu
# 212              Aaron Hunter
# 213           James Delgrande
# 214           Marius Lindauer
# 215            Holger H. Hoos
# 216              Frank Hutter
# 217            Torsten Schaub
# 218              Piotr Krysta
# 219           Orestis Telelis
# 220            Carmine Ventre
# 221           Johan Kwisthout
# 222              Tatsuya Imai
# 223             Alex Fukunaga
# 224       Andreas Steigmiller
# 225               Birte Glimm
# 226              Ben Strasser
# 227                 Adi Botea
# 228            Daniel Harabor
# 229                Haris Aziz
# 230              Markus Brill
# 231             Felix Fischer
# 232          Paul Harrenstein
# 233               Jerome Lang
# 234         Hans Georg Seedig
# 235     Fazlul Hasan Siddiqui
# 236             Patrik Haslum
# 237         Joseph Y. Halpern
# 238              Igor Rochlin
# 239               David Sarne
#
#                                            affliations  \
# 0    University of the Federal Armed Forces Hamburg...
# 1                                                 Null
# 2    Priv. Dozent and Senior Scientist, Vienna Univ...
# 3    Department of Electrical and Computer Engineer...
# 4     Amirkabir University of Technology, Tehran, Iran
# 5                                                 Null
# 6    AGH University of Science and Technology, Krak...
# 7                         Strategic Sourcing at Airbnb
# 8                           Paris Descartes University
# 9    Institute for Logic, Language and Computation ...
# 10                           LIP6, Sorbonne Universit‚
# 11                                 Unknown affiliation
# 12   University of Bremen, Faculty of Mathematics, ...
# 13   University of Bremen, Institute of Computer Sc...
# 14                       University of Bremen, Germany
# 15   Professor of Computer Science, Friedrich-Alexa...
# 16                  The University of British Columbia
# 17            Simon Fraser University, Burnaby, Canada
# 18   University of Alberta, Philosophy, Faculty Member
# 19   Professor of Computing Science, Simon Fraser U...
# 20                                 IBM Research, Haifa
# 21                               King's College London
# 22   Professor of Computer Science, Cornell University
# 23                                 Unknown affiliation
# 24                      Los Alamos National Laboratory
# 25   Associate Professor, Singapore Management Univ...
# 26                              HEC Montréal and GERAD
# 27              Dugald C. Jackson Professor, EECS, MIT
# 28             Physicist at Federal University of Para
# 29          Pontificia Universidade Católica do Paraná
# ..                                                 ...
# 210                                               Null
# 211                 GuangDong University of Technology
# 212                           University of Notre Dame
# 213  Simon Fraser University · School of Computing ...
# 214                             University of Freiburg
# 215  Leiden University | LEI · Leiden Institute of ...
# 216  University of Freiburg | Albert-Ludwigs-Univer...
# 217                     University of Potsdam, Germany
# 218                        University of Liverpool, UK
# 219                              University of Piraeus
# 220                              King's College London
# 221  Radboud University | RU · Business and Law Res...
# 222  Nanzan University · Department of British and ...
# 223                                Harvard University
# 224                                     Ulm University
# 225                                     Ulm University
# 226  Karlsruhe Institute of Technology | KIT · Inst...
# 227             IBM · Smarter Cities Technology Centre
# 228                      Monash University (Australia)
# 229  National ICT Australia Ltd | NICTA · Optimisat...
# 230                      Technische Universität Berlin
# 231              Lawrence Berkeley National Laboratory
# 232     Post-doctoral researcher, University of Oxford
# 233                                     chercheur CNRS
# 234                     Technische Universität München
# 235  Dhaka University of Engineering & Technology, ...
# 236  Australian National University | ANU · College...
# 237  Cornell University | CU · Department of Comput...
# 238  College of Management Academic Studies · Schoo...
# 239                              University of Chicago
#
#                                          article_title                   doi  \
# 0               Solving the Torpedo Scheduling Problem  10.1613/jair.1.11303
# 1               Solving the Torpedo Scheduling Problem  10.1613/jair.1.11303
# 2               Solving the Torpedo Scheduling Problem  10.1613/jair.1.11303
# 3    Xeggora: Exploiting Immune-to-Evidence Symmetr...  10.1613/jair.1.11322
# 4    Xeggora: Exploiting Immune-to-Evidence Symmetr...  10.1613/jair.1.11322
# 5    Recognizing Top-Monotonic Preference Profiles ...  10.1613/jair.1.11331
# 6    Recognizing Top-Monotonic Preference Profiles ...  10.1613/jair.1.11331
# 7    Rationalisation of Profiles of Abstract Argume...     10.1613/jair.5436
# 8    Rationalisation of Profiles of Abstract Argume...     10.1613/jair.5436
# 9    Rationalisation of Profiles of Abstract Argume...     10.1613/jair.5436
# 10   Rationalisation of Profiles of Abstract Argume...     10.1613/jair.5436
# 11   Rationalisation of Profiles of Abstract Argume...     10.1613/jair.5436
# 12   Probabilistic Description Logics for Subjectiv...     10.1613/jair.5222
# 13   Probabilistic Description Logics for Subjectiv...     10.1613/jair.5222
# 14   Probabilistic Description Logics for Subjectiv...     10.1613/jair.5222
# 15   Probabilistic Description Logics for Subjectiv...     10.1613/jair.5222
# 16              Kernel Contraction and Base Dependence     10.1613/jair.5496
# 17              Kernel Contraction and Base Dependence     10.1613/jair.5496
# 18              Kernel Contraction and Base Dependence     10.1613/jair.5496
# 19              Kernel Contraction and Base Dependence     10.1613/jair.5496
# 20   The Computational Complexity of Structure-Base...     10.1613/jair.5229
# 21   The Computational Complexity of Structure-Base...     10.1613/jair.5229
# 22   The Computational Complexity of Structure-Base...     10.1613/jair.5229
# 23   The Computational Complexity of Structure-Base...     10.1613/jair.5229
# 24   Dynamic Repositioning to Reduce Lost Demand in...     10.1613/jair.5308
# 25   Dynamic Repositioning to Reduce Lost Demand in...     10.1613/jair.5308
# 26   Dynamic Repositioning to Reduce Lost Demand in...     10.1613/jair.5308
# 27   Dynamic Repositioning to Reduce Lost Demand in...     10.1613/jair.5308
# 28   Using Collective Behavior of Coupled Oscillato...  10.1613/jair.1.11468
# 29   Using Collective Behavior of Coupled Oscillato...  10.1613/jair.1.11468
# ..                                                 ...                   ...
# 210  Topic-Based Dissimilarity and Sensitivity Mode...     10.1613/jair.4265
# 211  Topic-Based Dissimilarity and Sensitivity Mode...     10.1613/jair.4265
# 212      Belief Change with Uncertain Action Histories     10.1613/jair.4558
# 213      Belief Change with Uncertain Action Histories     10.1613/jair.4558
# 214  AutoFolio: An Automatically Configured Algorit...     10.1613/jair.4726
# 215  AutoFolio: An Automatically Configured Algorit...     10.1613/jair.4726
# 216  AutoFolio: An Automatically Configured Algorit...     10.1613/jair.4726
# 217  AutoFolio: An Automatically Configured Algorit...     10.1613/jair.4726
# 218  Mechanisms for Multi-unit Combinatorial Auctio...     10.1613/jair.4587
# 219  Mechanisms for Multi-unit Combinatorial Auctio...     10.1613/jair.4587
# 220  Mechanisms for Multi-unit Combinatorial Auctio...     10.1613/jair.4587
# 221  Tree-Width and the Computational Complexity of...     10.1613/jair.4794
# 222  On a Practical,  Integer-Linear Programming Mo...     10.1613/jair.4936
# 223  On a Practical,  Integer-Linear Programming Mo...     10.1613/jair.4936
# 224  Pay-As-You-Go Description Logic Reasoning by C...     10.1613/jair.4897
# 225  Pay-As-You-Go Description Logic Reasoning by C...     10.1613/jair.4897
# 226  Compressing Optimal Paths with Run Length Enco...     10.1613/jair.4931
# 227  Compressing Optimal Paths with Run Length Enco...     10.1613/jair.4931
# 228  Compressing Optimal Paths with Run Length Enco...     10.1613/jair.4931
# 229  Possible and Necessary Winners of Partial Tour...     10.1613/jair.4856
# 230  Possible and Necessary Winners of Partial Tour...     10.1613/jair.4856
# 231  Possible and Necessary Winners of Partial Tour...     10.1613/jair.4856
# 232  Possible and Necessary Winners of Partial Tour...     10.1613/jair.4856
# 233  Possible and Necessary Winners of Partial Tour...     10.1613/jair.4856
# 234  Possible and Necessary Winners of Partial Tour...     10.1613/jair.4856
# 235               Continuing Plan Quality Optimisation     10.1613/jair.4980
# 236               Continuing Plan Quality Optimisation     10.1613/jair.4980
# 237  Weighted Regret-Based Likelihood: A New Approa...     10.1613/jair.4859
# 238  Constraining Information Sharing to Improve Co...     10.1613/jair.4613
# 239  Constraining Information Sharing to Improve Co...     10.1613/jair.4613
#
#              volume     type
# 0    Vol. 66 (2019)  article
# 1    Vol. 66 (2019)  article
# 2    Vol. 66 (2019)  article
# 3    Vol. 66 (2019)  article
# 4    Vol. 66 (2019)  article
# 5    Vol. 66 (2019)  article
# 6    Vol. 66 (2019)  article
# 7    Vol. 60 (2017)  article
# 8    Vol. 60 (2017)  article
# 9    Vol. 60 (2017)  article
# 10   Vol. 60 (2017)  article
# 11   Vol. 60 (2017)  article
# 12   Vol. 58 (2017)  article
# 13   Vol. 58 (2017)  article
# 14   Vol. 58 (2017)  article
# 15   Vol. 58 (2017)  article
# 16   Vol. 60 (2017)  article
# 17   Vol. 60 (2017)  article
# 18   Vol. 60 (2017)  article
# 19   Vol. 60 (2017)  article
# 20   Vol. 58 (2017)  article
# 21   Vol. 58 (2017)  article
# 22   Vol. 58 (2017)  article
# 23   Vol. 58 (2017)  article
# 24   Vol. 58 (2017)  article
# 25   Vol. 58 (2017)  article
# 26   Vol. 58 (2017)  article
# 27   Vol. 58 (2017)  article
# 28   Vol. 64 (2019)  article
# 29   Vol. 64 (2019)  article
# ..              ...      ...
# 210  Vol. 50 (2014)  article
# 211  Vol. 50 (2014)  article
# 212  Vol. 53 (2015)  article
# 213  Vol. 53 (2015)  article
# 214  Vol. 53 (2015)  article
# 215  Vol. 53 (2015)  article
# 216  Vol. 53 (2015)  article
# 217  Vol. 53 (2015)  article
# 218  Vol. 53 (2015)  article
# 219  Vol. 53 (2015)  article
# 220  Vol. 53 (2015)  article
# 221  Vol. 53 (2015)  article
# 222  Vol. 54 (2015)  article
# 223  Vol. 54 (2015)  article
# 224  Vol. 54 (2015)  article
# 225  Vol. 54 (2015)  article
# 226  Vol. 54 (2015)  article
# 227  Vol. 54 (2015)  article
# 228  Vol. 54 (2015)  article
# 229  Vol. 54 (2015)  article
# 230  Vol. 54 (2015)  article
# 231  Vol. 54 (2015)  article
# 232  Vol. 54 (2015)  article
# 233  Vol. 54 (2015)  article
# 234  Vol. 54 (2015)  article
# 235  Vol. 54 (2015)  article
# 236  Vol. 54 (2015)  article
# 237  Vol. 54 (2015)  article
# 238  Vol. 54 (2015)  article
# 239  Vol. 54 (2015)  article
#
# [240 rows x 6 columns]

# %%
col_names = data.columns
col_names
# Out:
# Index(['author_name', 'affliations', 'article_title', 'doi', 'volume', 'type'], dtype='object')

# %%
list_of_dict = []
for i in range(data.shape[0]):
    dict= {}
    for name in col_names:
        dict[name]=data.loc[i,name]
    list_of_dict.append(dict)
list_of_dict
# Out:
# [{'author_name': 'Martin Josef Geiger',
#   'affliations': 'University of the Federal Armed Forces Hamburg, Germany',
#   'article_title': 'Solving the Torpedo Scheduling Problem',
#   'doi': '10.1613/jair.1.11303',
#   'volume': 'Vol. 66 (2019)',
#   'type': 'article'},
#  {'author_name': 'Lucas Kletzander',
#   'affliations': 'Null',
#   'article_title': 'Solving the Torpedo Scheduling Problem',
#   'doi': '10.1613/jair.1.11303',
#   'volume': 'Vol. 66 (2019)',
#   'type': 'article'},
#  {'author_name': 'Nysret Musliu',
#   'affliations': 'Priv. Dozent and Senior Scientist, Vienna University of Technology',
#   'article_title': 'Solving the Torpedo Scheduling Problem',
#   'doi': '10.1613/jair.1.11303',
#   'volume': 'Vol. 66 (2019)',
#   'type': 'article'},
#  {'author_name': 'Mohammad Mahdi Amirian',
#   'affliations': 'Department of Electrical and Computer Engineering Isfahan University of Technology Isfahan, Iran',
#   'article_title': 'Xeggora: Exploiting Immune-to-Evidence Symmetries with Full Aggregation in Statistical Relational Models',
#   'doi': '10.1613/jair.1.11322',
#   'volume': 'Vol. 66 (2019)',
#   'type': 'article'},
#  {'author_name': 'Saeed Shiry Ghidary',
#   'affliations': 'Amirkabir University of Technology, Tehran, Iran',
#   'article_title': 'Xeggora: Exploiting Immune-to-Evidence Symmetries with Full Aggregation in Statistical Relational Models',
#   'doi': '10.1613/jair.1.11322',
#   'volume': 'Vol. 66 (2019)',
#   'type': 'article'},
#  {'author_name': 'Krzysztof Magiera',
#   'affliations': 'Null',
#   'article_title': 'Recognizing Top-Monotonic Preference Profiles in Polynomial Time',
#   'doi': '10.1613/jair.1.11331',
#   'volume': 'Vol. 66 (2019)',
#   'type': 'article'},
#  {'author_name': 'Piotr Faliszewski',
#   'affliations': 'AGH University of Science and Technology, Krakow, Poland',
#   'article_title': 'Recognizing Top-Monotonic Preference Profiles in Polynomial Time',
#   'doi': '10.1613/jair.1.11331',
#   'volume': 'Vol. 66 (2019)',
#   'type': 'article'},
#  {'author_name': 'St‚phane Airiau',
#   'affliations': 'Strategic Sourcing at Airbnb',
#   'article_title': 'Rationalisation of Profiles of Abstract Argumentation Frameworks: Characterisation and Complexity',
#   'doi': '10.1613/jair.5436',
#   'volume': 'Vol. 60 (2017)',
#   'type': 'article'},
#  {'author_name': 'Elise Bonzon',
#   'affliations': 'Paris Descartes University',
#   'article_title': 'Rationalisation of Profiles of Abstract Argumentation Frameworks: Characterisation and Complexity',
#   'doi': '10.1613/jair.5436',
#   'volume': 'Vol. 60 (2017)',
#   'type': 'article'},
#  {'author_name': 'Ulle Endriss',
#   'affliations': 'Institute for Logic, Language and Computation University of Amsterdam',
#   'article_title': 'Rationalisation of Profiles of Abstract Argumentation Frameworks: Characterisation and Complexity',
#   'doi': '10.1613/jair.5436',
#   'volume': 'Vol. 60 (2017)',
#   'type': 'article'},
#  {'author_name': 'Nicolas Maudet',
#   'affliations': 'LIP6, Sorbonne Universit‚',
#   'article_title': 'Rationalisation of Profiles of Abstract Argumentation Frameworks: Characterisation and Complexity',
#   'doi': '10.1613/jair.5436',
#   'volume': 'Vol. 60 (2017)',
#   'type': 'article'},
#  {'author_name': 'Julien Rossit',
#   'affliations': 'Unknown affiliation',
#   'article_title': 'Rationalisation of Profiles of Abstract Argumentation Frameworks: Characterisation and Complexity',
#   'doi': '10.1613/jair.5436',
#   'volume': 'Vol. 60 (2017)',
#   'type': 'article'},
#  {'author_name': 'Victor Gutierrez-Basulto',
#   'affliations': 'University of Bremen, Faculty of Mathematics, Computer Science',
#   'article_title': 'Probabilistic Description Logics for Subjective Uncertainty',
#   'doi': '10.1613/jair.5222',
#   'volume': 'Vol. 58 (2017)',
#   'type': 'article'},
#  {'author_name': 'Jean Christoph Jung',
#   'affliations': 'University of Bremen, Institute of Computer Science, Germany',
#   'article_title': 'Probabilistic Description Logics for Subjective Uncertainty',
#   'doi': '10.1613/jair.5222',
#   'volume': 'Vol. 58 (2017)',
#   'type': 'article'},
#  {'author_name': 'Carsten Lutz',
#   'affliations': 'University of Bremen, Germany',
#   'article_title': 'Probabilistic Description Logics for Subjective Uncertainty',
#   'doi': '10.1613/jair.5222',
#   'volume': 'Vol. 58 (2017)',
#   'type': 'article'},
#  {'author_name': 'Lutz Schr”der',
#   'affliations': 'Professor of Computer Science, Friedrich-Alexander-Universit„t Erlangen-N\x81rnberg',
#   'article_title': 'Probabilistic Description Logics for Subjective Uncertainty',
#   'doi': '10.1613/jair.5222',
#   'volume': 'Vol. 58 (2017)',
#   'type': 'article'},
#  {'author_name': 'Mehrdad Oveisi',
#   'affliations': 'The University of British Columbia',
#   'article_title': 'Kernel Contraction and Base Dependence',
#   'doi': '10.1613/jair.5496',
#   'volume': 'Vol. 60 (2017)',
#   'type': 'article'},
#  {'author_name': 'James P. Delgrande',
#   'affliations': 'Simon Fraser University, Burnaby, Canada',
#   'article_title': 'Kernel Contraction and Base Dependence',
#   'doi': '10.1613/jair.5496',
#   'volume': 'Vol. 60 (2017)',
#   'type': 'article'},
#  {'author_name': 'Francis Jeffry Pelletier',
#   'affliations': 'University of Alberta, Philosophy, Faculty Member',
#   'article_title': 'Kernel Contraction and Base Dependence',
#   'doi': '10.1613/jair.5496',
#   'volume': 'Vol. 60 (2017)',
#   'type': 'article'},
#  {'author_name': 'Fred Popowich',
#   'affliations': 'Professor of Computing Science, Simon Fraser University',
#   'article_title': 'Kernel Contraction and Base Dependence',
#   'doi': '10.1613/jair.5496',
#   'volume': 'Vol. 60 (2017)',
#   'type': 'article'},
#  {'author_name': 'Gadi Aleksandrowicz',
#   'affliations': 'IBM Research, Haifa',
#   'article_title': 'The Computational Complexity of Structure-Based Causality',
#   'doi': '10.1613/jair.5229',
#   'volume': 'Vol. 58 (2017)',
#   'type': 'article'},
#  {'author_name': 'Hana Chockler',
#   'affliations': "King's College London",
#   'article_title': 'The Computational Complexity of Structure-Based Causality',
#   'doi': '10.1613/jair.5229',
#   'volume': 'Vol. 58 (2017)',
#   'type': 'article'},
#  {'author_name': 'Joseph Y. Halpern',
#   'affliations': 'Professor of Computer Science,\xa0Cornell University',
#   'article_title': 'The Computational Complexity of Structure-Based Causality',
#   'doi': '10.1613/jair.5229',
#   'volume': 'Vol. 58 (2017)',
#   'type': 'article'},
#  {'author_name': 'Alexander Ivrii',
#   'affliations': 'Unknown affiliation',
#   'article_title': 'The Computational Complexity of Structure-Based Causality',
#   'doi': '10.1613/jair.5229',
#   'volume': 'Vol. 58 (2017)',
#   'type': 'article'},
#  {'author_name': 'Supriyo Ghosh',
#   'affliations': 'Los Alamos National Laboratory',
#   'article_title': 'Dynamic Repositioning to Reduce Lost Demand in Bike Sharing Systems',
#   'doi': '10.1613/jair.5308',
#   'volume': 'Vol. 58 (2017)',
#   'type': 'article'},
#  {'author_name': 'Pradeep Varakantham',
#   'affliations': 'Associate Professor,\xa0Singapore Management University',
#   'article_title': 'Dynamic Repositioning to Reduce Lost Demand in Bike Sharing Systems',
#   'doi': '10.1613/jair.5308',
#   'volume': 'Vol. 58 (2017)',
#   'type': 'article'},
#  {'author_name': 'Yossiri Adulyasak',
#   'affliations': 'HEC Montréal\xa0and GERAD',
#   'article_title': 'Dynamic Repositioning to Reduce Lost Demand in Bike Sharing Systems',
#   'doi': '10.1613/jair.5308',
#   'volume': 'Vol. 58 (2017)',
#   'type': 'article'},
#  {'author_name': 'Patrick Jaillet',
#   'affliations': 'Dugald C. Jackson Professor, EECS,\xa0MIT',
#   'article_title': 'Dynamic Repositioning to Reduce Lost Demand in Bike Sharing Systems',
#   'doi': '10.1613/jair.5308',
#   'volume': 'Vol. 58 (2017)',
#   'type': 'article'},
#  {'author_name': 'Allan R. Leite',
#   'affliations': 'Physicist at\xa0Federal University of Para',
#   'article_title': 'Using Collective Behavior of Coupled Oscillators for Solving DCOP',
#   'doi': '10.1613/jair.1.11468',
#   'volume': 'Vol. 64 (2019)',
#   'type': 'article'},
#  {'author_name': 'Fabricio Enembreck',
#   'affliations': 'Pontificia Universidade Católica do Paraná',
#   'article_title': 'Using Collective Behavior of Coupled Oscillators for Solving DCOP',
#   'doi': '10.1613/jair.1.11468',
#   'volume': 'Vol. 64 (2019)',
#   'type': 'article'},
#  {'author_name': 'Carlo Combi',
#   'affliations': 'Professor of Computer Science,\xa0University of Verona',
#   'article_title': 'Conditional Simple Temporal Networks with Uncertainty and Resources',
#   'doi': '10.1613/jair.1.11453',
#   'volume': 'Vol. 64 (2019)',
#   'type': 'article'},
#  {'author_name': 'Roberto Posenato',
#   'affliations': 'Associate Professor of Computer Science,\xa0University of Verona\xa0(Italy)',
#   'article_title': 'Conditional Simple Temporal Networks with Uncertainty and Resources',
#   'doi': '10.1613/jair.1.11453',
#   'volume': 'Vol. 64 (2019)',
#   'type': 'article'},
#  {'author_name': 'Luca Vigano',
#   'affliations': "Professor of Computer Science and Head of the Cybersecurity Group, Department of Informatics, King's",
#   'article_title': 'Conditional Simple Temporal Networks with Uncertainty and Resources',
#   'doi': '10.1613/jair.1.11453',
#   'volume': 'Vol. 64 (2019)',
#   'type': 'article'},
#  {'author_name': 'Matteo Zavatteri',
#   'affliations': 'University of Verona',
#   'article_title': 'Conditional Simple Temporal Networks with Uncertainty and Resources',
#   'doi': '10.1613/jair.1.11453',
#   'volume': 'Vol. 64 (2019)',
#   'type': 'article'},
#  {'author_name': 'Heshan Du',
#   'affliations': 'University of Nottingham Ningbo China',
#   'article_title': 'Qualitative Spatial Logics for Buffered Geometries',
#   'doi': '10.1613/jair.5140',
#   'volume': 'Vol. 56 (2016)',
#   'type': 'article'},
#  {'author_name': 'Natasha Alechina',
#   'affliations': 'Department of Information and Computing Sciences,\xa0University of Utrecht',
#   'article_title': 'Qualitative Spatial Logics for Buffered Geometries',
#   'doi': '10.1613/jair.5140',
#   'volume': 'Vol. 56 (2016)',
#   'type': 'article'},
#  {'author_name': 'Isabel Cenamor',
#   'affliations': 'Universidad Carlos III de Madrid',
#   'article_title': 'The IBaCoP Planning System: Instance-Based Configured Portfolios',
#   'doi': '10.1613/jair.5080',
#   'volume': 'Vol. 56 (2016)',
#   'type': 'article'},
#  {'author_name': 'Tom\xa0s de la Rosa',
#   'affliations': 'Professor of Petrology and Geochemistry, CIQSO,\xa0Universidad de Huelva',
#   'article_title': 'The IBaCoP Planning System: Instance-Based Configured Portfolios',
#   'doi': '10.1613/jair.5080',
#   'volume': 'Vol. 56 (2016)',
#   'type': 'article'},
#  {'author_name': 'Fernando Fern\xa0ndez',
#   'affliations': 'University Carlos III de Madrid',
#   'article_title': 'The IBaCoP Planning System: Instance-Based Configured Portfolios',
#   'doi': '10.1613/jair.5080',
#   'volume': 'Vol. 56 (2016)',
#   'type': 'article'},
#  {'author_name': 'Cristhian Ariel D. Deagustini',
#   'affliations': 'Universidad Nacional del Sur | UNS · Institute for Computer Science and Engineering',
#   'article_title': 'Datalog+- Ontology Consolidation',
#   'doi': '10.1613/jair.5131',
#   'volume': 'Vol. 56 (2016)',
#   'type': 'article'},
#  {'author_name': 'Maria Vanina Martinez',
#   'affliations': 'National Scientific and Technical Research Council | conicet · ICIC CONICET- UNS - Instituto de Ciencias e Ingeniería de la Computación',
#   'article_title': 'Datalog+- Ontology Consolidation',
#   'doi': '10.1613/jair.5131',
#   'volume': 'Vol. 56 (2016)',
#   'type': 'article'},
#  {'author_name': 'Marcelo A. Falappa',
#   'affliations': 'Universidad Nacional del Sur | UNS · Departamento de Ciencias e Ingeniería de la Computación',
#   'article_title': 'Datalog+- Ontology Consolidation',
#   'doi': '10.1613/jair.5131',
#   'volume': 'Vol. 56 (2016)',
#   'type': 'article'},
#  {'author_name': 'Guillermo R. Simari',
#   'affliations': 'Universidad Nacional del Sur | UNS · Departamento de Ciencias e Ingeniería de la Computación',
#   'article_title': 'Datalog+- Ontology Consolidation',
#   'doi': '10.1613/jair.5131',
#   'volume': 'Vol. 56 (2016)',
#   'type': 'article'},
#  {'author_name': 'Broes De Cat',
#   'affliations': 'Senior product analist, OM Partner',
#   'article_title': 'Lazy Model Expansion: Interleaving Grounding with Search',
#   'doi': '10.1613/jair.4591',
#   'volume': 'Vol. 52 (2015)',
#   'type': 'article'},
#  {'author_name': 'Marc Denecker',
#   'affliations': 'Prof. at KU-Leuven',
#   'article_title': 'Lazy Model Expansion: Interleaving Grounding with Search',
#   'doi': '10.1613/jair.4591',
#   'volume': 'Vol. 52 (2015)',
#   'type': 'article'},
#  {'author_name': 'Maurice Bruynooghe',
#   'affliations': 'Professor Em. of Computer Science, KULeuven',
#   'article_title': 'Lazy Model Expansion: Interleaving Grounding with Search',
#   'doi': '10.1613/jair.4591',
#   'volume': 'Vol. 52 (2015)',
#   'type': 'article'},
#  {'author_name': 'Peter Stuckey',
#   'affliations': 'Faculty of Information Technology, Monash University',
#   'article_title': 'Lazy Model Expansion: Interleaving Grounding with Search',
#   'doi': '10.1613/jair.4591',
#   'volume': 'Vol. 52 (2015)',
#   'type': 'article'},
#  {'author_name': 'Haris Aziz',
#   'affliations': 'UNSW Sydney and Data61 CSIRO',
#   'article_title': 'A Study of Proxies for Shapley Allocations of Transport Costs',
#   'doi': '10.1613/jair.5021',
#   'volume': 'Vol. 56 (2016)',
#   'type': 'article'},
#  {'author_name': 'Casey Cahan',
#   'affliations': 'University of Auckland',
#   'article_title': 'A Study of Proxies for Shapley Allocations of Transport Costs',
#   'doi': '10.1613/jair.5021',
#   'volume': 'Vol. 56 (2016)',
#   'type': 'article'},
#  {'author_name': 'Charles Gretton',
#   'affliations': 'The Australian National University',
#   'article_title': 'A Study of Proxies for Shapley Allocations of Transport Costs',
#   'doi': '10.1613/jair.5021',
#   'volume': 'Vol. 56 (2016)',
#   'type': 'article'},
#  {'author_name': 'Philip Kilby',
#   'affliations': 'CSIRO Data61',
#   'article_title': 'A Study of Proxies for Shapley Allocations of Transport Costs',
#   'doi': '10.1613/jair.5021',
#   'volume': 'Vol. 56 (2016)',
#   'type': 'article'},
#  {'author_name': 'Nicholas Mattei',
#   'affliations': 'Assistant Professor, Tulane University',
#   'article_title': 'A Study of Proxies for Shapley Allocations of Transport Costs',
#   'doi': '10.1613/jair.5021',
#   'volume': 'Vol. 56 (2016)',
#   'type': 'article'},
#  {'author_name': 'Toby Walsh',
#   'affliations': 'Professor, TU Berlin, UNSW, and Data61',
#   'article_title': 'A Study of Proxies for Shapley Allocations of Transport Costs',
#   'doi': '10.1613/jair.5021',
#   'volume': 'Vol. 56 (2016)',
#   'type': 'article'},
#  {'author_name': 'B. Bosansky',
#   'affliations': 'Assistant Professor, Dept. of Computer Science, FEE, Czech Technical University in Prague',
#   'article_title': 'An Exact Double-Oracle Algorithm for Zero-Sum Extensive-Form Games with Imperfect Information',
#   'doi': '10.1613/jair.4477',
#   'volume': 'Vol. 51 (2014)',
#   'type': 'article'},
#  {'author_name': 'C. Kiekintveld',
#   'affliations': 'University of Texas at El Paso',
#   'article_title': 'An Exact Double-Oracle Algorithm for Zero-Sum Extensive-Form Games with Imperfect Information',
#   'doi': '10.1613/jair.4477',
#   'volume': 'Vol. 51 (2014)',
#   'type': 'article'},
#  {'author_name': 'V. Lisy',
#   'affliations': 'Professor of Physics, Technical University of Kosice, Slovakia',
#   'article_title': 'An Exact Double-Oracle Algorithm for Zero-Sum Extensive-Form Games with Imperfect Information',
#   'doi': '10.1613/jair.4477',
#   'volume': 'Vol. 51 (2014)',
#   'type': 'article'},
#  {'author_name': 'M. Pechoucek',
#   'affliations': 'Professor of Computer Science, Czech Technical University, Head of Agent Technology Center',
#   'article_title': 'An Exact Double-Oracle Algorithm for Zero-Sum Extensive-Form Games with Imperfect Information',
#   'doi': '10.1613/jair.4477',
#   'volume': 'Vol. 51 (2014)',
#   'type': 'article'},
#  {'author_name': 'Haonan Yu',
#   'affliations': 'Research Scientist, Horizon Robotics',
#   'article_title': 'A Compositional Framework for Grounding Language Inference, Generation, and Acquisition in Video',
#   'doi': '10.1613/jair.4556',
#   'volume': 'Vol. 52 (2015)',
#   'type': 'article'},
#  {'author_name': 'N. Siddharth',
#   'affliations': 'Senior Researcher, University of Oxford',
#   'article_title': 'A Compositional Framework for Grounding Language Inference, Generation, and Acquisition in Video',
#   'doi': '10.1613/jair.4556',
#   'volume': 'Vol. 52 (2015)',
#   'type': 'article'},
#  {'author_name': 'Andrei Barbu',
#   'affliations': 'MIT, CSAIL',
#   'article_title': 'A Compositional Framework for Grounding Language Inference, Generation, and Acquisition in Video',
#   'doi': '10.1613/jair.4556',
#   'volume': 'Vol. 52 (2015)',
#   'type': 'article'},
#  {'author_name': 'Jeffrey Mark Siskind',
#   'affliations': 'Purdue University',
#   'article_title': 'A Compositional Framework for Grounding Language Inference, Generation, and Acquisition in Video',
#   'doi': '10.1613/jair.4556',
#   'volume': 'Vol. 52 (2015)',
#   'type': 'article'},
#  {'author_name': 'D. Zilli',
#   'affliations': 'Research Postgraduate, University of Southampton',
#   'article_title': 'A Hidden Markov Model-Based Acoustic Cicada Detector for Crowdsourced Smartphone Biodiversity Monitoring',
#   'doi': '10.1613/jair.4434',
#   'volume': 'Vol. 51 (2014)',
#   'type': 'article'},
#  {'author_name': 'O. Parson',
#   'affliations': 'Senior Data Scientist, Bulb',
#   'article_title': 'A Hidden Markov Model-Based Acoustic Cicada Detector for Crowdsourced Smartphone Biodiversity Monitoring',
#   'doi': '10.1613/jair.4434',
#   'volume': 'Vol. 51 (2014)',
#   'type': 'article'},
#  {'author_name': 'G. V. Merrett',
#   'affliations': 'Professor, University of Southampton | Head of Centre for IoT and Pervasive Systems',
#   'article_title': 'A Hidden Markov Model-Based Acoustic Cicada Detector for Crowdsourced Smartphone Biodiversity Monitoring',
#   'doi': '10.1613/jair.4434',
#   'volume': 'Vol. 51 (2014)',
#   'type': 'article'},
#  {'author_name': 'A. Rogers',
#   'affliations': 'Simpson/Querrey Professor, Northwestern University',
#   'article_title': 'A Hidden Markov Model-Based Acoustic Cicada Detector for Crowdsourced Smartphone Biodiversity Monitoring',
#   'doi': '10.1613/jair.4434',
#   'volume': 'Vol. 51 (2014)',
#   'type': 'article'},
#  {'author_name': 'P. Kissmann',
#   'affliations': 'Universität des Saarlandes',
#   'article_title': 'BDD Ordering Heuristics for Classical Planning',
#   'doi': '10.1613/jair.4586',
#   'volume': 'Vol. 51 (2014)',
#   'type': 'article'},
#  {'author_name': 'J. Hoffmann',
#   'affliations': 'Professor of Sociology, Brigham Young University',
#   'article_title': 'BDD Ordering Heuristics for Classical Planning',
#   'doi': '10.1613/jair.4586',
#   'volume': 'Vol. 51 (2014)',
#   'type': 'article'},
#  {'author_name': 'C. R. Shelton',
#   'affliations': 'Professor, University of California, Riverside',
#   'article_title': 'Tutorial on Structured Continuous-Time Markov Processes',
#   'doi': '10.1613/jair.4415',
#   'volume': 'Vol. 51 (2014)',
#   'type': 'article'},
#  {'author_name': 'G. Ciardo',
#   'affliations': 'Iowa State University',
#   'article_title': 'Tutorial on Structured Continuous-Time Markov Processes',
#   'doi': '10.1613/jair.4415',
#   'volume': 'Vol. 51 (2014)',
#   'type': 'article'},
#  {'author_name': 'G. Stefanoni',
#   'affliations': 'Unknown affiliation',
#   'article_title': 'The Complexity of Answering Conjunctive and Navigational Queries over OWL 2 EL Knowledge Bases',
#   'doi': '10.1613/jair.4457',
#   'volume': 'Vol. 51 (2014)',
#   'type': 'article'},
#  {'author_name': 'B. Motik',
#   'affliations': 'Professor of Computer Science, Oxford University',
#   'article_title': 'The Complexity of Answering Conjunctive and Navigational Queries over OWL 2 EL Knowledge Bases',
#   'doi': '10.1613/jair.4457',
#   'volume': 'Vol. 51 (2014)',
#   'type': 'article'},
#  {'author_name': 'M. Kroetzsch',
#   'affliations': 'Technische Universität Dresden',
#   'article_title': 'The Complexity of Answering Conjunctive and Navigational Queries over OWL 2 EL Knowledge Bases',
#   'doi': '10.1613/jair.4457',
#   'volume': 'Vol. 51 (2014)',
#   'type': 'article'},
#  {'author_name': 'S. Rudolph',
#   'affliations': 'Helmholtz-Zentrum für Umweltforschung',
#   'article_title': 'The Complexity of Answering Conjunctive and Navigational Queries over OWL 2 EL Knowledge Bases',
#   'doi': '10.1613/jair.4457',
#   'volume': 'Vol. 51 (2014)',
#   'type': 'article'},
#  {'author_name': 'O. Cepek',
#   'affliations': 'Norwegian University of Life Sciences (NMBU) · Department of Animal and Aquacultural Sciences (IHA)',
#   'article_title': 'On Minimum Representations of Matched Formulas',
#   'doi': '10.1613/jair.4517',
#   'volume': 'Vol. 51 (2014)',
#   'type': 'article'},
#  {'author_name': 'S. Gursky',
#   'affliations': 'Unknown affiliation',
#   'article_title': 'On Minimum Representations of Matched Formulas',
#   'doi': '10.1613/jair.4517',
#   'volume': 'Vol. 51 (2014)',
#   'type': 'article'},
#  {'author_name': 'P. Kucera',
#   'affliations': 'PhD student of human geography, Charles University in Prague',
#   'article_title': 'On Minimum Representations of Matched Formulas',
#   'doi': '10.1613/jair.4517',
#   'volume': 'Vol. 51 (2014)',
#   'type': 'article'},
#  {'author_name': 'P. Nguyen',
#   'affliations': 'University Paris 1 Pantheon Sorbonne & ESCP Europe',
#   'article_title': 'Using Meta-mining to Support Data Mining Workflow Planning and Optimization',
#   'doi': '10.1613/jair.4377',
#   'volume': 'Vol. 51 (2014)',
#   'type': 'article'},
#  {'author_name': 'M. Hilario',
#   'affliations': 'University of Geneva',
#   'article_title': 'Using Meta-mining to Support Data Mining Workflow Planning and Optimization',
#   'doi': '10.1613/jair.4377',
#   'volume': 'Vol. 51 (2014)',
#   'type': 'article'},
#  {'author_name': 'A. Kalousis',
#   'affliations': 'University of Applied Sciences, Western Switzerland (HES-SO)',
#   'article_title': 'Using Meta-mining to Support Data Mining Workflow Planning and Optimization',
#   'doi': '10.1613/jair.4377',
#   'volume': 'Vol. 51 (2014)',
#   'type': 'article'},
#  {'author_name': 'I. Kash',
#   'affliations': 'University of Illinois at Chicago',
#   'article_title': 'No Agent Left Behind: Dynamic Fair Division of Multiple Resources',
#   'doi': '10.1613/jair.4405',
#   'volume': 'Vol. 51 (2014)',
#   'type': 'article'},
#  {'author_name': 'A. D. Procaccia',
#   'affliations': 'Carnegie Mellon University',
#   'article_title': 'No Agent Left Behind: Dynamic Fair Division of Multiple Resources',
#   'doi': '10.1613/jair.4405',
#   'volume': 'Vol. 51 (2014)',
#   'type': 'article'},
#  {'author_name': 'N. Shah',
#   'affliations': 'Forschungszentrum Jülich · Institute of Neuroscience and Medicine - 4 (INM-4)',
#   'article_title': 'No Agent Left Behind: Dynamic Fair Division of Multiple Resources',
#   'doi': '10.1613/jair.4405',
#   'volume': 'Vol. 51 (2014)',
#   'type': 'article'},
#  {'author_name': 'D. Cohen',
#   'affliations': 'W. D. Hamilton Professor of Complex Systems, Information & Public Policy, The University of Michigan',
#   'article_title': 'Iterative Plan Construction for the Workflow Satisfiability Problem',
#   'doi': '10.1613/jair.4435',
#   'volume': 'Vol. 51 (2014)',
#   'type': 'article'},
#  {'author_name': 'J. Crampton',
#   'affliations': 'Professor of Urban Data Analysis, Newcastle University',
#   'article_title': 'Iterative Plan Construction for the Workflow Satisfiability Problem',
#   'doi': '10.1613/jair.4435',
#   'volume': 'Vol. 51 (2014)',
#   'type': 'article'},
#  {'author_name': 'A. Gagarin',
#   'affliations': 'Saint Petersburg Electrotechnical University "LETI"',
#   'article_title': 'Iterative Plan Construction for the Workflow Satisfiability Problem',
#   'doi': '10.1613/jair.4435',
#   'volume': 'Vol. 51 (2014)',
#   'type': 'article'},
#  {'author_name': 'G. Gutin',
#   'affliations': 'Professor of Computer Science, Royal Holloway, University of London',
#   'article_title': 'Iterative Plan Construction for the Workflow Satisfiability Problem',
#   'doi': '10.1613/jair.4435',
#   'volume': 'Vol. 51 (2014)',
#   'type': 'article'},
#  {'author_name': 'M. Jones',
#   'affliations': 'Researcher, MERL',
#   'article_title': 'Iterative Plan Construction for the Workflow Satisfiability Problem',
#   'doi': '10.1613/jair.4435',
#   'volume': 'Vol. 51 (2014)',
#   'type': 'article'},
#  {'author_name': 'A. G. Cohn',
#   'affliations': 'Professor of Automated Reasoning,\xa0University of Leeds',
#   'article_title': 'Reasoning about Topological and Cardinal Direction Relations Between 2-Dimensional Spatial Objects',
#   'doi': '10.1613/jair.4513',
#   'volume': 'Vol. 51 (2014)',
#   'type': 'article'},
#  {'author_name': 'S. Li',
#   'affliations': 'Massachusetts Institute of Technology (MIT), Harvard University',
#   'article_title': 'Reasoning about Topological and Cardinal Direction Relations Between 2-Dimensional Spatial Objects',
#   'doi': '10.1613/jair.4513',
#   'volume': 'Vol. 51 (2014)',
#   'type': 'article'},
#  {'author_name': 'W. Liu',
#   'affliations': 'University of New South Wales, Sydney',
#   'article_title': 'Reasoning about Topological and Cardinal Direction Relations Between 2-Dimensional Spatial Objects',
#   'doi': '10.1613/jair.4513',
#   'volume': 'Vol. 51 (2014)',
#   'type': 'article'},
#  {'author_name': 'J. Renz',
#   'affliations': 'Professor,\xa0Australian National University',
#   'article_title': 'Reasoning about Topological and Cardinal Direction Relations Between 2-Dimensional Spatial Objects',
#   'doi': '10.1613/jair.4513',
#   'volume': 'Vol. 51 (2014)',
#   'type': 'article'},
#  {'author_name': 'A. Lopez-Ortiz',
#   'affliations': 'Professor and Cheriton Chair, University of Waterloo',
#   'article_title': 'Optimal Scheduling of Contract Algorithms for Anytime Problem-Solving',
#   'doi': '10.1613/jair.4360',
#   'volume': 'Vol. 51 (2014)',
#   'type': 'article'},
#  {'author_name': 'S. Angelopoulos',
#   'affliations': 'Assistant Professor, Tilburg University',
#   'article_title': 'Optimal Scheduling of Contract Algorithms for Anytime Problem-Solving',
#   'doi': '10.1613/jair.4360',
#   'volume': 'Vol. 51 (2014)',
#   'type': 'article'},
#  {'author_name': 'A. M. Hamel',
#   'affliations': 'University of Manitoba',
#   'article_title': 'Optimal Scheduling of Contract Algorithms for Anytime Problem-Solving',
#   'doi': '10.1613/jair.4360',
#   'volume': 'Vol. 51 (2014)',
#   'type': 'article'},
#  {'author_name': 'B. de Wilde',
#   'affliations': 'Independent Researcher\xa0·\xa0Laboratory',
#   'article_title': 'Push and Rotate: a Complete Multi-agent Pathfinding Algorithm',
#   'doi': '10.1613/jair.4447',
#   'volume': 'Vol. 51 (2014)',
#   'type': 'article'},
#  {'author_name': 'A. W. ter Mors',
#   'affliations': 'Delft University of Technology',
#   'article_title': 'Push and Rotate: a Complete Multi-agent Pathfinding Algorithm',
#   'doi': '10.1613/jair.4447',
#   'volume': 'Vol. 51 (2014)',
#   'type': 'article'},
#  {'author_name': 'C. Witteveen',
#   'affliations': 'Professor of algorithmics, Delft University of Technology',
#   'article_title': 'Push and Rotate: a Complete Multi-agent Pathfinding Algorithm',
#   'doi': '10.1613/jair.4447',
#   'volume': 'Vol. 51 (2014)',
#   'type': 'article'},
#  {'author_name': 'S. Cai',
#   'affliations': 'Associate Professor of Mechanics, BeiHang University',
#   'article_title': 'Scoring Functions Based on Second Level Score for k-SAT with Long Clauses',
#   'doi': '10.1613/jair.4480',
#   'volume': 'Vol. 51 (2014)',
#   'type': 'article'},
#  {'author_name': 'C. Luo',
#   'affliations': 'Researcher, Microsoft Research Asia',
#   'article_title': 'Scoring Functions Based on Second Level Score for k-SAT with Long Clauses',
#   'doi': '10.1613/jair.4480',
#   'volume': 'Vol. 51 (2014)',
#   'type': 'article'},
#  {'author_name': 'K. Su',
#   'affliations': 'University of Cambrige',
#   'article_title': 'Scoring Functions Based on Second Level Score for k-SAT with Long Clauses',
#   'doi': '10.1613/jair.4480',
#   'volume': 'Vol. 51 (2014)',
#   'type': 'article'},
#  {'author_name': 'A. Metodi',
#   'affliations': 'Cadence Israel Development Center',
#   'article_title': 'A Novel SAT-Based Approach to Model Based Diagnosis',
#   'doi': '10.1613/jair.4503',
#   'volume': 'Vol. 51 (2014)',
#   'type': 'article'},
#  {'author_name': 'R. Stern',
#   'affliations': 'University of Sheffield',
#   'article_title': 'A Novel SAT-Based Approach to Model Based Diagnosis',
#   'doi': '10.1613/jair.4503',
#   'volume': 'Vol. 51 (2014)',
#   'type': 'article'},
#  {'author_name': 'M. Kalech',
#   'affliations': 'Ben-Gurion University',
#   'article_title': 'A Novel SAT-Based Approach to Model Based Diagnosis',
#   'doi': '10.1613/jair.4503',
#   'volume': 'Vol. 51 (2014)',
#   'type': 'article'},
#  {'author_name': 'M. Codish',
#   'affliations': 'Department of Computer Science, Ben-Gurion University of the Negev',
#   'article_title': 'A Novel SAT-Based Approach to Model Based Diagnosis',
#   'doi': '10.1613/jair.4503',
#   'volume': 'Vol. 51 (2014)',
#   'type': 'article'},
#  {'author_name': 'F. Belardinelli',
#   'affliations': "Université d'Evry",
#   'article_title': 'Verification of Agent-Based Artifact Systems',
#   'doi': '10.1613/jair.4424',
#   'volume': 'Vol. 51 (2014)',
#   'type': 'article'},
#  {'author_name': 'A. Lomuscio',
#   'affliations': 'Imperial College London',
#   'article_title': 'Verification of Agent-Based Artifact Systems',
#   'doi': '10.1613/jair.4424',
#   'volume': 'Vol. 51 (2014)',
#   'type': 'article'},
#  {'author_name': 'F. Patrizi',
#   'affliations': 'Senior Researcher, DIAG - Sapienza University of Rome',
#   'article_title': 'Verification of Agent-Based Artifact Systems',
#   'doi': '10.1613/jair.4424',
#   'volume': 'Vol. 51 (2014)',
#   'type': 'article'},
#  {'author_name': 'R. Nissim',
#   'affliations': 'Engineering Group Manager, Autonomous Driving Simulation, General Motors Israel',
#   'article_title': 'Distributed Heuristic Forward Search for Multi-agent Planning',
#   'doi': '10.1613/jair.4295',
#   'volume': 'Vol. 51 (2014)',
#   'type': 'article'},
#  {'author_name': 'R. Brafman',
#   'affliations': 'Department of Computer Science, Ben-Gurion University',
#   'article_title': 'Distributed Heuristic Forward Search for Multi-agent Planning',
#   'doi': '10.1613/jair.4295',
#   'volume': 'Vol. 51 (2014)',
#   'type': 'article'},
#  {'author_name': 'C. Bäckström',
#   'affliations': 'University of Minnesota Duluth',
#   'article_title': 'Automaton Plans',
#   'doi': '10.1613/jair.4391',
#   'volume': 'Vol. 51 (2014)',
#   'type': 'article'},
#  {'author_name': 'A. Jonsson',
#   'affliations': 'Swedish Institute of Computer Science',
#   'article_title': 'Automaton Plans',
#   'doi': '10.1613/jair.4391',
#   'volume': 'Vol. 51 (2014)',
#   'type': 'article'},
#  {'author_name': 'P. Jonsson',
#   'affliations': 'Professor of Applied Mathematics, Malmö University',
#   'article_title': 'Automaton Plans',
#   'doi': '10.1613/jair.4391',
#   'volume': 'Vol. 51 (2014)',
#   'type': 'article'},
#  {'author_name': 'Z. Zhuang',
#   'affliations': 'Professor, College of Intelligence and Computing, Tianjin University',
#   'article_title': 'Entrenchment-Based Horn Contraction',
#   'doi': '10.1613/jair.4430',
#   'volume': 'Vol. 51 (2014)',
#   'type': 'article'},
#  {'author_name': 'M. Pagnucco',
#   'affliations': 'Professor, The University of New South Wales',
#   'article_title': 'Entrenchment-Based Horn Contraction',
#   'doi': '10.1613/jair.4430',
#   'volume': 'Vol. 51 (2014)',
#   'type': 'article'},
#  {'author_name': 'A. Adiga',
#   'affliations': 'Biocomplexity Institute & Initiative, University of Virginia',
#   'article_title': 'Sensitivity of Diffusion Dynamics to Network Uncertainty',
#   'doi': '10.1613/jair.4330',
#   'volume': 'Vol. 51 (2014)',
#   'type': 'article'},
#  {'author_name': 'C. J. Kuhlman',
#   'affliations': 'Network Dynamics and Simulation Science Lab, Biocomplexity Institute, Virginia Tech',
#   'article_title': 'Sensitivity of Diffusion Dynamics to Network Uncertainty',
#   'doi': '10.1613/jair.4330',
#   'volume': 'Vol. 51 (2014)',
#   'type': 'article'},
#  {'author_name': 'H. S. Mortveit',
#   'affliations': 'Virginia Polytechnic Institute and State University | VT · NDSSL & Department of Mathematics',
#   'article_title': 'Sensitivity of Diffusion Dynamics to Network Uncertainty',
#   'doi': '10.1613/jair.4330',
#   'volume': 'Vol. 51 (2014)',
#   'type': 'article'},
#  {'author_name': 'A. K. S. Vullikanti',
#   'affliations': 'Null',
#   'article_title': 'Sensitivity of Diffusion Dynamics to Network Uncertainty',
#   'doi': '10.1613/jair.4330',
#   'volume': 'Vol. 51 (2014)',
#   'type': 'article'},
#  {'author_name': 'Z. Feldman',
#   'affliations': 'Professor of Mathematics Education, Boston University',
#   'article_title': 'Simple Regret Optimization in Online Planning for Markov Decision Processes',
#   'doi': '10.1613/jair.4432',
#   'volume': 'Vol. 51 (2014)',
#   'type': 'article'},
#  {'author_name': 'C. Domshlak',
#   'affliations': 'Professor, Technion',
#   'article_title': 'Simple Regret Optimization in Online Planning for Markov Decision Processes',
#   'doi': '10.1613/jair.4432',
#   'volume': 'Vol. 51 (2014)',
#   'type': 'article'},
#  {'author_name': 'K. Woodsend',
#   'affliations': 'University of Edinburgh',
#   'article_title': 'Text Rewriting Improves Semantic Role Labeling',
#   'doi': '10.1613/jair.4431',
#   'volume': 'Vol. 51 (2014)',
#   'type': 'article'},
#  {'author_name': 'M. Lapata',
#   'affliations': 'School of Informatics, Edinburgh University',
#   'article_title': 'Text Rewriting Improves Semantic Role Labeling',
#   'doi': '10.1613/jair.4431',
#   'volume': 'Vol. 51 (2014)',
#   'type': 'article'},
#  {'author_name': 'M. Winikoff',
#   'affliations': 'Professor, Victoria University of Wellington, New Zealand',
#   'article_title': 'On the Testability of BDI Agent Systems',
#   'doi': '10.1613/jair.4458',
#   'volume': 'Vol. 51 (2014)',
#   'type': 'article'},
#  {'author_name': 'S. Cranefield',
#   'affliations': 'Professor of Information Science, University of Otago',
#   'article_title': 'On the Testability of BDI Agent Systems',
#   'doi': '10.1613/jair.4458',
#   'volume': 'Vol. 51 (2014)',
#   'type': 'article'},
#  {'author_name': 'R. Micalizio',
#   'affliations': 'Università di Torino',
#   'article_title': 'Cooperative Monitoring to Diagnose Multiagent Plans',
#   'doi': '10.1613/jair.4339',
#   'volume': 'Vol. 51 (2014)',
#   'type': 'article'},
#  {'author_name': 'P. Torasso',
#   'affliations': 'Null',
#   'article_title': 'Cooperative Monitoring to Diagnose Multiagent Plans',
#   'doi': '10.1613/jair.4339',
#   'volume': 'Vol. 51 (2014)',
#   'type': 'article'},
#  {'author_name': 'B. Bonet',
#   'affliations': 'Professor of Computer Science, Universidad Simón Bolívar, Caracas, Venezuela',
#   'article_title': 'Belief Tracking for Planning with Sensing: Width, Complexity and Approximations',
#   'doi': '10.1613/jair.4475',
#   'volume': 'Vol. 50 (2014)',
#   'type': 'article'},
#  {'author_name': 'H. Geffner',
#   'affliations': 'ICREA & Universitat Pompeu Fabra, Artificial Intelligence and Machine Learning Group, DTIC',
#   'article_title': 'Belief Tracking for Planning with Sensing: Width, Complexity and Approximations',
#   'doi': '10.1613/jair.4475',
#   'volume': 'Vol. 50 (2014)',
#   'type': 'article'},
#  {'author_name': 'Y. Zick',
#   'affliations': 'National University of Singapore',
#   'article_title': 'Arbitration and Stability in Cooperative Games with Overlapping Coalitions',
#   'doi': '10.1613/jair.4237',
#   'volume': 'Vol. 50 (2014)',
#   'type': 'article'},
#  {'author_name': 'E. Markakis',
#   'affliations': 'Athens University of Economics and Business',
#   'article_title': 'Arbitration and Stability in Cooperative Games with Overlapping Coalitions',
#   'doi': '10.1613/jair.4237',
#   'volume': 'Vol. 50 (2014)',
#   'type': 'article'},
#  {'author_name': 'E. Elkind',
#   'affliations': 'University of Oxford',
#   'article_title': 'Arbitration and Stability in Cooperative Games with Overlapping Coalitions',
#   'doi': '10.1613/jair.4237',
#   'volume': 'Vol. 50 (2014)',
#   'type': 'article'},
#  {'author_name': 'U. Thayasivam',
#   'affliations': 'Senior Lecturer Department of Computer Science and Engineering, University of Moratuwa',
#   'article_title': 'Speeding Up Iterative Ontology Alignment using Block-Coordinate Descent',
#   'doi': '10.1613/jair.4366',
#   'volume': 'Vol. 50 (2014)',
#   'type': 'article'},
#  {'author_name': 'P. Doshi',
#   'affliations': 'National Chemical Laboratory, Pune, India',
#   'article_title': 'Speeding Up Iterative Ontology Alignment using Block-Coordinate Descent',
#   'doi': '10.1613/jair.4366',
#   'volume': 'Vol. 50 (2014)',
#   'type': 'article'},
#  {'author_name': 'A. Veit',
#   'affliations': 'Null',
#   'article_title': 'Demand Side Energy Management via Multiagent Coordination in Consumer Cooperatives',
#   'doi': '10.1613/jair.4416',
#   'volume': 'Vol. 50 (2014)',
#   'type': 'article'},
#  {'author_name': 'Y. Xu',
#   'affliations': 'Chinese Academy of Sciences | CAS',
#   'article_title': 'Demand Side Energy Management via Multiagent Coordination in Consumer Cooperatives',
#   'doi': '10.1613/jair.4416',
#   'volume': 'Vol. 50 (2014)',
#   'type': 'article'},
#  {'author_name': 'R. Zheng',
#   'affliations': 'Computing and Software, McMaster University; Computer Science, University of Houston',
#   'article_title': 'Demand Side Energy Management via Multiagent Coordination in Consumer Cooperatives',
#   'doi': '10.1613/jair.4416',
#   'volume': 'Vol. 50 (2014)',
#   'type': 'article'},
#  {'author_name': 'N. Chakraborty',
#   'affliations': 'Department of Mechanical Engineering, Stony Brook University',
#   'article_title': 'Demand Side Energy Management via Multiagent Coordination in Consumer Cooperatives',
#   'doi': '10.1613/jair.4416',
#   'volume': 'Vol. 50 (2014)',
#   'type': 'article'},
#  {'author_name': 'K. Sycara',
#   'affliations': 'Professor School of Computer Science, Carnegie Mellon University',
#   'article_title': 'Demand Side Energy Management via Multiagent Coordination in Consumer Cooperatives',
#   'doi': '10.1613/jair.4416',
#   'volume': 'Vol. 50 (2014)',
#   'type': 'article'},
#  {'author_name': 'A. M. S. Barreto',
#   'affliations': 'Null',
#   'article_title': 'Policy Iteration Based on Stochastic Factorization',
#   'doi': '10.1613/jair.4301',
#   'volume': 'Vol. 50 (2014)',
#   'type': 'article'},
#  {'author_name': 'J. Pineau',
#   'affliations': 'School of Computer Science, McGill University',
#   'article_title': 'Policy Iteration Based on Stochastic Factorization',
#   'doi': '10.1613/jair.4301',
#   'volume': 'Vol. 50 (2014)',
#   'type': 'article'},
#  {'author_name': 'D. Precup',
#   'affliations': 'DeepMind and McGill University',
#   'article_title': 'Policy Iteration Based on Stochastic Factorization',
#   'doi': '10.1613/jair.4301',
#   'volume': 'Vol. 50 (2014)',
#   'type': 'article'},
#  {'author_name': 'S. Kiritchenko',
#   'affliations': 'National Research Council Canada',
#   'article_title': 'Sentiment Analysis of Short Informal Texts',
#   'doi': '10.1613/jair.4272',
#   'volume': 'Vol. 50 (2014)',
#   'type': 'article'},
#  {'author_name': 'X. Zhu',
#   'affliations': 'Associate Professor of Health Management and Policy, University of Iowa',
#   'article_title': 'Sentiment Analysis of Short Informal Texts',
#   'doi': '10.1613/jair.4272',
#   'volume': 'Vol. 50 (2014)',
#   'type': 'article'},
#  {'author_name': 'S. M. Mohammad',
#   'affliations': 'Senior Research Scientist, National Research Council Canada',
#   'article_title': 'Sentiment Analysis of Short Informal Texts',
#   'doi': '10.1613/jair.4272',
#   'volume': 'Vol. 50 (2014)',
#   'type': 'article'},
#  {'author_name': 'D. Bergman',
#   'affliations': 'University of Connecticut',
#   'article_title': 'MDD Propagation for Sequence Constraints',
#   'doi': '10.1613/jair.4199',
#   'volume': 'Vol. 50 (2014)',
#   'type': 'article'},
#  {'author_name': 'A. A. Cire',
#   'affliations': 'Assistant Professor, University of Toronto Scarborough and Rotman School of Management',
#   'article_title': 'MDD Propagation for Sequence Constraints',
#   'doi': '10.1613/jair.4199',
#   'volume': 'Vol. 50 (2014)',
#   'type': 'article'},
#  {'author_name': 'W. van Hoeve',
#   'affliations': 'Tide Microfluidics',
#   'article_title': 'MDD Propagation for Sequence Constraints',
#   'doi': '10.1613/jair.4199',
#   'volume': 'Vol. 50 (2014)',
#   'type': 'article'},
#  {'author_name': 'A. Gerevini',
#   'affliations': 'Università degli Studi di Brescia',
#   'article_title': 'Planning through Automatic Portfolio Configuration: The PbP Approach',
#   'doi': '10.1613/jair.4359',
#   'volume': 'Vol. 50 (2014)',
#   'type': 'article'},
#  {'author_name': 'A. Saetti',
#   'affliations': 'Università degli Studi di Brescia | UNIBS',
#   'article_title': 'Planning through Automatic Portfolio Configuration: The PbP Approach',
#   'doi': '10.1613/jair.4359',
#   'volume': 'Vol. 50 (2014)',
#   'type': 'article'},
#  {'author_name': 'M. Vallati',
#   'affliations': 'Senior Lecturer, University of Huddersfield',
#   'article_title': 'Planning through Automatic Portfolio Configuration: The PbP Approach',
#   'doi': '10.1613/jair.4359',
#   'volume': 'Vol. 50 (2014)',
#   'type': 'article'},
#  {'author_name': 'D. D. Maua',
#   'affliations': 'Professor, Dept. of Computer Science, Institute of Mathematics and Statistics, Universidade de São',
#   'article_title': 'Probabilistic Inference in Credal Networks: New Complexity Results',
#   'doi': '10.1613/jair.435',
#   'volume': 'Vol. 50 (2014)',
#   'type': 'article'},
#  {'author_name': 'C. P. de Campos',
#   'affliations': 'Eindhoven University of Technology',
#   'article_title': 'Probabilistic Inference in Credal Networks: New Complexity Results',
#   'doi': '10.1613/jair.435',
#   'volume': 'Vol. 50 (2014)',
#   'type': 'article'},
#  {'author_name': 'A. Benavoli',
#   'affliations': 'Senior Lecturer, CSIS, University of Limerick',
#   'article_title': 'Probabilistic Inference in Credal Networks: New Complexity Results',
#   'doi': '10.1613/jair.435',
#   'volume': 'Vol. 50 (2014)',
#   'type': 'article'},
#  {'author_name': 'A. Antonucci',
#   'affliations': 'EPFL',
#   'article_title': 'Probabilistic Inference in Credal Networks: New Complexity Results',
#   'doi': '10.1613/jair.435',
#   'volume': 'Vol. 50 (2014)',
#   'type': 'article'},
#  {'author_name': 'A. Rey',
#   'affliations': 'Professor of Physical Chemistry',
#   'article_title': 'False-Name Manipulation in Weighted Voting Games is Hard for Probabilistic Polynomial Time',
#   'doi': '10.1613/jair.4293',
#   'volume': 'Vol. 50 (2014)',
#   'type': 'article'},
#  {'author_name': 'J. Rothe',
#   'affliations': 'Professor of Computer Science, Heinrich-Heine-Universität Düsseldorf',
#   'article_title': 'False-Name Manipulation in Weighted Voting Games is Hard for Probabilistic Polynomial Time',
#   'doi': '10.1613/jair.4293',
#   'volume': 'Vol. 50 (2014)',
#   'type': 'article'},
#  {'author_name': 'E. Keyder',
#   'affliations': 'Postdoctoral researcher, INRIA',
#   'article_title': 'Improving Delete Relaxation Heuristics Through Explicitly Represented Conjunctions',
#   'doi': '10.1613/jair.4277',
#   'volume': 'Vol. 50 (2014)',
#   'type': 'article'},
#  {'author_name': 'J. Hoffmann',
#   'affliations': 'Professor of Computer Science, Saarland Informatics Campus, Saarland University, Saarbruecken',
#   'article_title': 'Improving Delete Relaxation Heuristics Through Explicitly Represented Conjunctions',
#   'doi': '10.1613/jair.4277',
#   'volume': 'Vol. 50 (2014)',
#   'type': 'article'},
#  {'author_name': 'P. Haslum',
#   'affliations': 'Unknown affiliation',
#   'article_title': 'Improving Delete Relaxation Heuristics Through Explicitly Represented Conjunctions',
#   'doi': '10.1613/jair.4277',
#   'volume': 'Vol. 50 (2014)',
#   'type': 'article'},
#  {'author_name': 'D. Terekhov',
#   'affliations': 'Assistant Professor, Industrial Engineering, Concordia University',
#   'article_title': 'Integrating Queueing Theory and Scheduling for Dynamic Scheduling Problems',
#   'doi': '10.1613/jair.4278',
#   'volume': 'Vol. 50 (2014)',
#   'type': 'article'},
#  {'author_name': 'T. T. Tran',
#   'affliations': 'University of Massachusetts, Amherst. Twitter, Inc. LinkedIn',
#   'article_title': 'Integrating Queueing Theory and Scheduling for Dynamic Scheduling Problems',
#   'doi': '10.1613/jair.4278',
#   'volume': 'Vol. 50 (2014)',
#   'type': 'article'},
#  {'author_name': 'D. G. Down',
#   'affliations': 'McMaster University',
#   'article_title': 'Integrating Queueing Theory and Scheduling for Dynamic Scheduling Problems',
#   'doi': '10.1613/jair.4278',
#   'volume': 'Vol. 50 (2014)',
#   'type': 'article'},
#  {'author_name': 'J.C. Beck',
#   'affliations': 'Professor of Mechanical and Industrial Engineering, University of Toronto',
#   'article_title': 'Integrating Queueing Theory and Scheduling for Dynamic Scheduling Problems',
#   'doi': '10.1613/jair.4278',
#   'volume': 'Vol. 50 (2014)',
#   'type': 'article'},
#  {'author_name': 'M. Cooper',
#   'affliations': 'Professor of Physics & Astronomy, University of California Irvine',
#   'article_title': 'Monotone Temporal Planning: Tractability, Extensions and Applications',
#   'doi': '10.1613/jair.4358',
#   'volume': 'Vol. 50 (2014)',
#   'type': 'article'},
#  {'author_name': 'F. Maris',
#   'affliations': 'Associate Professor of Computer Science, University of Toulouse',
#   'article_title': 'Monotone Temporal Planning: Tractability, Extensions and Applications',
#   'doi': '10.1613/jair.4358',
#   'volume': 'Vol. 50 (2014)',
#   'type': 'article'},
#  {'author_name': 'P. Régnier',
#   'affliations': 'ULB',
#   'article_title': 'Monotone Temporal Planning: Tractability, Extensions and Applications',
#   'doi': '10.1613/jair.4358',
#   'volume': 'Vol. 50 (2014)',
#   'type': 'article'},
#  {'author_name': 'R. Bredereck',
#   'affliations': 'TU Berlin',
#   'article_title': 'A Multivariate Complexity Analysis of Lobbying in Multiple Referenda',
#   'doi': '10.1613/jair.4285',
#   'volume': 'Vol. 50 (2014)',
#   'type': 'article'},
#  {'author_name': 'J. Chen',
#   'affliations': 'Prof. of Computer Science, Queens College',
#   'article_title': 'A Multivariate Complexity Analysis of Lobbying in Multiple Referenda',
#   'doi': '10.1613/jair.4285',
#   'volume': 'Vol. 50 (2014)',
#   'type': 'article'},
#  {'author_name': 'S. Hartung',
#   'affliations': 'University of Hamburg',
#   'article_title': 'A Multivariate Complexity Analysis of Lobbying in Multiple Referenda',
#   'doi': '10.1613/jair.4285',
#   'volume': 'Vol. 50 (2014)',
#   'type': 'article'},
#  {'author_name': 'S. Kratsch',
#   'affliations': 'Professor at Humboldt University Berlin',
#   'article_title': 'A Multivariate Complexity Analysis of Lobbying in Multiple Referenda',
#   'doi': '10.1613/jair.4285',
#   'volume': 'Vol. 50 (2014)',
#   'type': 'article'},
#  {'author_name': 'R. Niedermeier',
#   'affliations': 'Professor of Theoretical Computer Science, TU Berlin',
#   'article_title': 'A Multivariate Complexity Analysis of Lobbying in Multiple Referenda',
#   'doi': '10.1613/jair.4285',
#   'volume': 'Vol. 50 (2014)',
#   'type': 'article'},
#  {'author_name': 'O. Suchy',
#   'affliations': 'Assistant Professor of Theoretical Computer Science, Czech Technical University',
#   'article_title': 'A Multivariate Complexity Analysis of Lobbying in Multiple Referenda',
#   'doi': '10.1613/jair.4285',
#   'volume': 'Vol. 50 (2014)',
#   'type': 'article'},
#  {'author_name': 'G. J. Woeginger',
#   'affliations': 'Professor of Computer Science, RWTH Aachen',
#   'article_title': 'A Multivariate Complexity Analysis of Lobbying in Multiple Referenda',
#   'doi': '10.1613/jair.4285',
#   'volume': 'Vol. 50 (2014)',
#   'type': 'article'},
#  {'author_name': 'J.R. Doppa',
#   'affliations': 'George and Joan Berry Chair Assistant Professor, Computer Science, Washington State University',
#   'article_title': 'HC-Search: A Learning Framework for Search-based Structured Prediction',
#   'doi': '10.1613/jair.4212',
#   'volume': 'Vol. 50 (2014)',
#   'type': 'article'},
#  {'author_name': 'A. Fern',
#   'affliations': 'Oregon State University',
#   'article_title': 'HC-Search: A Learning Framework for Search-based Structured Prediction',
#   'doi': '10.1613/jair.4212',
#   'volume': 'Vol. 50 (2014)',
#   'type': 'article'},
#  {'author_name': 'P. Tadepalli',
#   'affliations': 'Professor of Computer Science, Oregon State University',
#   'article_title': 'HC-Search: A Learning Framework for Search-based Structured Prediction',
#   'doi': '10.1613/jair.4212',
#   'volume': 'Vol. 50 (2014)',
#   'type': 'article'},
#  {'author_name': 'F.M. Delle Fave',
#   'affliations': 'Mind Foundry ltd.',
#   'article_title': 'Game-Theoretic Patrolling with Dynamic Execution Uncertainty and a Case Study on a Real Transit System',
#   'doi': '10.1613/jair.4317',
#   'volume': 'Vol. 50 (2014)',
#   'type': 'article'},
#  {'author_name': 'A.X. Jiang',
#   'affliations': 'Assistant Professor of Computer Science, Trinity University',
# ...
#   'doi': '10.1613/jair.4317',
#   'volume': 'Vol. 50 (2014)',
#   'type': 'article'},
#  {'author_name': 'C. Zhang',
#   'affliations': 'University of Washington',
#   'article_title': 'Game-Theoretic Patrolling with Dynamic Execution Uncertainty and a Case Study on a Real Transit System',
#   'doi': '10.1613/jair.4317',
#   'volume': 'Vol. 50 (2014)',
#   'type': 'article'},
#  {'author_name': 'M. Tambe',
#   'affliations': 'Director CRCS Center & CS Professor @Harvard; Director "AI for Social Good" @Google Research India',
#   'article_title': 'Game-Theoretic Patrolling with Dynamic Execution Uncertainty and a Case Study on a Real Transit System',
#   'doi': '10.1613/jair.4317',
#   'volume': 'Vol. 50 (2014)',
#   'type': 'article'},
#  {'author_name': 'S. Kraus',
#   'affliations': 'Professor Of Computer Science, Bar-Ilan University',
#   'article_title': 'Game-Theoretic Patrolling with Dynamic Execution Uncertainty and a Case Study on a Real Transit System',
#   'doi': '10.1613/jair.4317',
#   'volume': 'Vol. 50 (2014)',
#   'type': 'article'},
#  {'author_name': 'J. P. Sullivan',
#   'affliations': 'Null',
#   'article_title': 'Game-Theoretic Patrolling with Dynamic Execution Uncertainty and a Case Study on a Real Transit System',
#   'doi': '10.1613/jair.4317',
#   'volume': 'Vol. 50 (2014)',
#   'type': 'article'},
#  {'author_name': 'M. Suda',
#   'affliations': 'Czech Technical University in Prague',
#   'article_title': 'Property Directed Reachability for Automated Planning',
#   'doi': '10.1613/jair.4231',
#   'volume': 'Vol. 50 (2014)',
#   'type': 'article'},
#  {'author_name': 'N. Rivera',
#   'affliations': 'Molecular Biology Institute of Barcelona ',
#   'article_title': 'Reconnection with the Ideal Tree: A New Approach to Real-Time Search',
#   'doi': '10.1613/jair.4292',
#   'volume': 'Vol. 50 (2014)',
#   'type': 'article'},
#  {'author_name': 'L. Illanes',
#   'affliations': 'PhD Student, University of Toronto',
#   'article_title': 'Reconnection with the Ideal Tree: A New Approach to Real-Time Search',
#   'doi': '10.1613/jair.4292',
#   'volume': 'Vol. 50 (2014)',
#   'type': 'article'},
#  {'author_name': 'J. A. Baier',
#   'affliations': 'Pontificia Universidad Católica de Chile',
#   'article_title': 'Reconnection with the Ideal Tree: A New Approach to Real-Time Search',
#   'doi': '10.1613/jair.4292',
#   'volume': 'Vol. 50 (2014)',
#   'type': 'article'},
#  {'author_name': 'C. Hernandez',
#   'affliations': 'Biomedical Engineering Department, Case Western Reserve University',
#   'article_title': 'Reconnection with the Ideal Tree: A New Approach to Real-Time Search',
#   'doi': '10.1613/jair.4292',
#   'volume': 'Vol. 50 (2014)',
#   'type': 'article'},
#  {'author_name': 'M. Goldenberg',
#   'affliations': 'Jerusalem College of Technology',
#   'article_title': 'Enhanced Partial Expansion A*',
#   'doi': '10.1613/jair.4171',
#   'volume': 'Vol. 50 (2014)',
#   'type': 'article'},
#  {'author_name': 'A. Felner',
#   'affliations': 'Ben-Gurion University',
#   'article_title': 'Enhanced Partial Expansion A*',
#   'doi': '10.1613/jair.4171',
#   'volume': 'Vol. 50 (2014)',
#   'type': 'article'},
#  {'author_name': 'R. Stern',
#   'affliations': 'University of Sheffield',
#   'article_title': 'Enhanced Partial Expansion A*',
#   'doi': '10.1613/jair.4171',
#   'volume': 'Vol. 50 (2014)',
#   'type': 'article'},
#  {'author_name': 'G. Sharon',
#   'affliations': 'Texas A&M University',
#   'article_title': 'Enhanced Partial Expansion A*',
#   'doi': '10.1613/jair.4171',
#   'volume': 'Vol. 50 (2014)',
#   'type': 'article'},
#  {'author_name': 'N. Sturtevant',
#   'affliations': 'University of Alberta',
#   'article_title': 'Enhanced Partial Expansion A*',
#   'doi': '10.1613/jair.4171',
#   'volume': 'Vol. 50 (2014)',
#   'type': 'article'},
#  {'author_name': 'R. C. Holte',
#   'affliations': 'University of Alberta',
#   'article_title': 'Enhanced Partial Expansion A*',
#   'doi': '10.1613/jair.4171',
#   'volume': 'Vol. 50 (2014)',
#   'type': 'article'},
#  {'author_name': 'J. Schaeffer',
#   'affliations': 'University of Alberta',
#   'article_title': 'Enhanced Partial Expansion A*',
#   'doi': '10.1613/jair.4171',
#   'volume': 'Vol. 50 (2014)',
#   'type': 'article'},
#  {'author_name': 'J. De Bock',
#   'affliations': 'Ghent University',
#   'article_title': 'An Efficient Algorithm for Estimating State Sequences in Imprecise Hidden Markov Models',
#   'doi': '10.1613/jair.4385',
#   'volume': 'Vol. 50 (2014)',
#   'type': 'article'},
#  {'author_name': 'G. de Cooman',
#   'affliations': 'Professor in Uncertainty Modelling and Systems Science, Ghent University',
#   'article_title': 'An Efficient Algorithm for Estimating State Sequences in Imprecise Hidden Markov Models',
#   'doi': '10.1613/jair.4385',
#   'volume': 'Vol. 50 (2014)',
#   'type': 'article'},
#  {'author_name': 'B. de Keijzer',
#   'affliations': 'Postdoctoral researcher, Centrum Wiskunde & Informatica (CWI)',
#   'article_title': 'Finding Optimal Solutions for Voting Game Design Problems',
#   'doi': '10.1613/jair.4109',
#   'volume': 'Vol. 50 (2014)',
#   'type': 'article'},
#  {'author_name': 'T. B. Klos',
#   'affliations': 'Assistant professor of Algorithmics, University of Utrecht',
#   'article_title': 'Finding Optimal Solutions for Voting Game Design Problems',
#   'doi': '10.1613/jair.4109',
#   'volume': 'Vol. 50 (2014)',
#   'type': 'article'},
#  {'author_name': 'Y. Zhang',
#   'affliations': 'University of Michigan',
#   'article_title': 'Finding Optimal Solutions for Voting Game Design Problems',
#   'doi': '10.1613/jair.4109',
#   'volume': 'Vol. 50 (2014)',
#   'type': 'article'},
#  {'author_name': 'A. Fern',
#   'affliations': 'Oregon State University',
#   'article_title': 'A Decision-Theoretic Model of Assistance',
#   'doi': '10.1613/jair.4213',
#   'volume': 'Vol. 50 (2014)',
#   'type': 'article'},
#  {'author_name': 'S. Natarajan',
#   'affliations': 'Professor of Agronomy, Annamalai University',
#   'article_title': 'A Decision-Theoretic Model of Assistance',
#   'doi': '10.1613/jair.4213',
#   'volume': 'Vol. 50 (2014)',
#   'type': 'article'},
#  {'author_name': 'K. Judah',
#   'affliations': 'Lookout, Inc.',
#   'article_title': 'A Decision-Theoretic Model of Assistance',
#   'doi': '10.1613/jair.4213',
#   'volume': 'Vol. 50 (2014)',
#   'type': 'article'},
#  {'author_name': 'P. Tadepalli',
#   'affliations': 'Professor of Computer Science, Oregon State University',
#   'article_title': 'A Decision-Theoretic Model of Assistance',
#   'doi': '10.1613/jair.4213',
#   'volume': 'Vol. 50 (2014)',
#   'type': 'article'},
#  {'author_name': 'Y. Wang',
#   'affliations': 'Professor, School of Information Engineering, Nanchang University',
#   'article_title': 'Knowledge Forgetting in Answer Set Programming',
#   'doi': '10.1613/jair.4297',
#   'volume': 'Vol. 50 (2014)',
#   'type': 'article'},
#  {'author_name': 'Y. Zhang',
#   'affliations': 'Post Doctoral Fellow in Bioinformatics, University of Texas Southwestern Medical Center',
#   'article_title': 'Knowledge Forgetting in Answer Set Programming',
#   'doi': '10.1613/jair.4297',
#   'volume': 'Vol. 50 (2014)',
#   'type': 'article'},
#  {'author_name': 'Y. Zhou',
#   'affliations': 'Unknown affiliation',
#   'article_title': 'Knowledge Forgetting in Answer Set Programming',
#   'doi': '10.1613/jair.4297',
#   'volume': 'Vol. 50 (2014)',
#   'type': 'article'},
#  {'author_name': 'M. Zhang',
#   'affliations': 'GE Healthcare',
#   'article_title': 'Knowledge Forgetting in Answer Set Programming',
#   'doi': '10.1613/jair.4297',
#   'volume': 'Vol. 50 (2014)',
#   'type': 'article'},
#  {'author_name': 'M. Zhang',
#   'affliations': 'GE Healthcare',
#   'article_title': 'Topic-Based Dissimilarity and Sensitivity Models for Translation Rule Selection',
#   'doi': '10.1613/jair.4265',
#   'volume': 'Vol. 50 (2014)',
#   'type': 'article'},
#  {'author_name': 'X. Xiao',
#   'affliations': 'Null',
#   'article_title': 'Topic-Based Dissimilarity and Sensitivity Models for Translation Rule Selection',
#   'doi': '10.1613/jair.4265',
#   'volume': 'Vol. 50 (2014)',
#   'type': 'article'},
#  {'author_name': 'D. Xiong',
#   'affliations': 'Null',
#   'article_title': 'Topic-Based Dissimilarity and Sensitivity Models for Translation Rule Selection',
#   'doi': '10.1613/jair.4265',
#   'volume': 'Vol. 50 (2014)',
#   'type': 'article'},
#  {'author_name': 'Q. Liu',
#   'affliations': 'GuangDong University of Technology',
#   'article_title': 'Topic-Based Dissimilarity and Sensitivity Models for Translation Rule Selection',
#   'doi': '10.1613/jair.4265',
#   'volume': 'Vol. 50 (2014)',
#   'type': 'article'},
#  {'author_name': 'Aaron Hunter',
#   'affliations': 'University of Notre Dame',
#   'article_title': 'Belief Change with Uncertain Action Histories',
#   'doi': '10.1613/jair.4558',
#   'volume': 'Vol. 53 (2015)',
#   'type': 'article'},
#  {'author_name': 'James Delgrande',
#   'affliations': 'Simon Fraser University · School of Computing Science',
#   'article_title': 'Belief Change with Uncertain Action Histories',
#   'doi': '10.1613/jair.4558',
#   'volume': 'Vol. 53 (2015)',
#   'type': 'article'},
#  {'author_name': 'Marius Lindauer',
#   'affliations': 'University of Freiburg',
#   'article_title': 'AutoFolio: An Automatically Configured Algorithm Selector',
#   'doi': '10.1613/jair.4726',
#   'volume': 'Vol. 53 (2015)',
#   'type': 'article'},
#  {'author_name': 'Holger H. Hoos',
#   'affliations': 'Leiden University | LEI · Leiden Institute of Advanced Computer Science',
#   'article_title': 'AutoFolio: An Automatically Configured Algorithm Selector',
#   'doi': '10.1613/jair.4726',
#   'volume': 'Vol. 53 (2015)',
#   'type': 'article'},
#  {'author_name': 'Frank Hutter',
#   'affliations': 'University of Freiburg | Albert-Ludwigs-Universität Freiburg · Department of Computer Science',
#   'article_title': 'AutoFolio: An Automatically Configured Algorithm Selector',
#   'doi': '10.1613/jair.4726',
#   'volume': 'Vol. 53 (2015)',
#   'type': 'article'},
#  {'author_name': 'Torsten Schaub',
#   'affliations': 'University of Potsdam, Germany',
#   'article_title': 'AutoFolio: An Automatically Configured Algorithm Selector',
#   'doi': '10.1613/jair.4726',
#   'volume': 'Vol. 53 (2015)',
#   'type': 'article'},
#  {'author_name': 'Piotr Krysta',
#   'affliations': 'University of Liverpool, UK',
#   'article_title': 'Mechanisms for Multi-unit Combinatorial Auctions with a Few Distinct Goods',
#   'doi': '10.1613/jair.4587',
#   'volume': 'Vol. 53 (2015)',
#   'type': 'article'},
#  {'author_name': 'Orestis Telelis',
#   'affliations': 'University of Piraeus',
#   'article_title': 'Mechanisms for Multi-unit Combinatorial Auctions with a Few Distinct Goods',
#   'doi': '10.1613/jair.4587',
#   'volume': 'Vol. 53 (2015)',
#   'type': 'article'},
#  {'author_name': 'Carmine Ventre',
#   'affliations': "King's College London",
#   'article_title': 'Mechanisms for Multi-unit Combinatorial Auctions with a Few Distinct Goods',
#   'doi': '10.1613/jair.4587',
#   'volume': 'Vol. 53 (2015)',
#   'type': 'article'},
#  {'author_name': 'Johan Kwisthout',
#   'affliations': 'Radboud University | RU · Business and Law Research Centre (OO&R)',
#   'article_title': 'Tree-Width and the Computational Complexity of MAP Approximations in Bayesian Networks',
#   'doi': '10.1613/jair.4794',
#   'volume': 'Vol. 53 (2015)',
#   'type': 'article'},
#  {'author_name': 'Tatsuya Imai',
#   'affliations': 'Nanzan University · Department of British and American Studies',
#   'article_title': 'On a Practical,  Integer-Linear Programming Model for Delete-Free Tasks and its Use as a Heuristic for Cost-Optimal Planning',
#   'doi': '10.1613/jair.4936',
#   'volume': 'Vol. 54 (2015)',
#   'type': 'article'},
#  {'author_name': 'Alex Fukunaga',
#   'affliations': 'Harvard University ',
#   'article_title': 'On a Practical,  Integer-Linear Programming Model for Delete-Free Tasks and its Use as a Heuristic for Cost-Optimal Planning',
#   'doi': '10.1613/jair.4936',
#   'volume': 'Vol. 54 (2015)',
#   'type': 'article'},
#  {'author_name': 'Andreas Steigmiller',
#   'affliations': 'Ulm University',
#   'article_title': 'Pay-As-You-Go Description Logic Reasoning by Coupling Tableau and Saturation Procedures',
#   'doi': '10.1613/jair.4897',
#   'volume': 'Vol. 54 (2015)',
#   'type': 'article'},
#  {'author_name': 'Birte Glimm',
#   'affliations': 'Ulm University',
#   'article_title': 'Pay-As-You-Go Description Logic Reasoning by Coupling Tableau and Saturation Procedures',
#   'doi': '10.1613/jair.4897',
#   'volume': 'Vol. 54 (2015)',
#   'type': 'article'},
#  {'author_name': 'Ben Strasser',
#   'affliations': 'Karlsruhe Institute of Technology | KIT · Institute of Theoretical Informatics',
#   'article_title': 'Compressing Optimal Paths with Run Length Encoding',
#   'doi': '10.1613/jair.4931',
#   'volume': 'Vol. 54 (2015)',
#   'type': 'article'},
#  {'author_name': 'Adi Botea',
#   'affliations': 'IBM · Smarter Cities Technology Centre',
#   'article_title': 'Compressing Optimal Paths with Run Length Encoding',
#   'doi': '10.1613/jair.4931',
#   'volume': 'Vol. 54 (2015)',
#   'type': 'article'},
#  {'author_name': 'Daniel Harabor',
#   'affliations': 'Monash University (Australia)',
#   'article_title': 'Compressing Optimal Paths with Run Length Encoding',
#   'doi': '10.1613/jair.4931',
#   'volume': 'Vol. 54 (2015)',
#   'type': 'article'},
#  {'author_name': 'Haris Aziz',
#   'affliations': 'National ICT Australia Ltd | NICTA · Optimisation Research Group (ORG@NICTA)',
#   'article_title': 'Possible and Necessary Winners of Partial Tournaments',
#   'doi': '10.1613/jair.4856',
#   'volume': 'Vol. 54 (2015)',
#   'type': 'article'},
#  {'author_name': 'Markus Brill',
#   'affliations': 'Technische Universität Berlin',
#   'article_title': 'Possible and Necessary Winners of Partial Tournaments',
#   'doi': '10.1613/jair.4856',
#   'volume': 'Vol. 54 (2015)',
#   'type': 'article'},
#  {'author_name': 'Felix Fischer',
#   'affliations': 'Lawrence Berkeley National Laboratory',
#   'article_title': 'Possible and Necessary Winners of Partial Tournaments',
#   'doi': '10.1613/jair.4856',
#   'volume': 'Vol. 54 (2015)',
#   'type': 'article'},
#  {'author_name': 'Paul Harrenstein',
#   'affliations': 'Post-doctoral researcher, University of Oxford',
#   'article_title': 'Possible and Necessary Winners of Partial Tournaments',
#   'doi': '10.1613/jair.4856',
#   'volume': 'Vol. 54 (2015)',
#   'type': 'article'},
#  {'author_name': 'Jerome Lang',
#   'affliations': 'chercheur CNRS',
#   'article_title': 'Possible and Necessary Winners of Partial Tournaments',
#   'doi': '10.1613/jair.4856',
#   'volume': 'Vol. 54 (2015)',
#   'type': 'article'},
#  {'author_name': 'Hans Georg Seedig',
#   'affliations': 'Technische Universität München',
#   'article_title': 'Possible and Necessary Winners of Partial Tournaments',
#   'doi': '10.1613/jair.4856',
#   'volume': 'Vol. 54 (2015)',
#   'type': 'article'},
#  {'author_name': 'Fazlul Hasan Siddiqui',
#   'affliations': 'Dhaka University of Engineering & Technology, Gazipur · Computer Science and Engineering',
#   'article_title': 'Continuing Plan Quality Optimisation',
#   'doi': '10.1613/jair.4980',
#   'volume': 'Vol. 54 (2015)',
#   'type': 'article'},
#  {'author_name': 'Patrik Haslum',
#   'affliations': 'Australian National University | ANU · College of Engineering & Computer Science',
#   'article_title': 'Continuing Plan Quality Optimisation',
#   'doi': '10.1613/jair.4980',
#   'volume': 'Vol. 54 (2015)',
#   'type': 'article'},
#  {'author_name': 'Joseph Y. Halpern',
#   'affliations': 'Cornell University | CU · Department of Computer Science',
#   'article_title': 'Weighted Regret-Based Likelihood: A New Approach to Describing Uncertainty',
#   'doi': '10.1613/jair.4859',
#   'volume': 'Vol. 54 (2015)',
#   'type': 'article'},
#  {'author_name': 'Igor Rochlin',
#   'affliations': 'College of Management Academic Studies · School of Computer Science',
#   'article_title': 'Constraining Information Sharing to Improve Cooperative Information Gathering',
#   'doi': '10.1613/jair.4613',
#   'volume': 'Vol. 54 (2015)',
#   'type': 'article'},
#  {'author_name': 'David Sarne',
#   'affliations': 'University of Chicago',
#   'article_title': 'Constraining Information Sharing to Improve Cooperative Information Gathering',
#   'doi': '10.1613/jair.4613',
#   'volume': 'Vol. 54 (2015)',
#   'type': 'article'}]
