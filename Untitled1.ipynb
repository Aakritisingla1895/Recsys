# %%
import numpy as np
import scipy
import pandas as pd
import math
import random
import sklearn
from nltk.corpus import stopwords
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from scipy.sparse.linalg import svds
import matplotlib.pyplot as plt

# %%
articles_df = pd.read_csv('ai_journal_articles_clean.csv')
articles_df = articles_df[articles_df['type'] == 'article']
articles_df.head(5)
# Out:
#    affliations                                       article_name  \
# 0          NaN             Solving the Torpedo Scheduling Problem
# 1          NaN  Xeggora: Exploiting Immune-to-Evidence Symmetr...
# 2          NaN  Recognizing Top-Monotonic Preference Profiles ...
# 3          NaN  Rationalisation of Profiles of Abstract Argume...
# 4          NaN  Probabilistic Description Logics for Subjectiv...
#
#                                              authors  \
# 0  Martin Josef Geiger,Lucas Kletzander,Nysret Mu...
# 1         Mohammad Mahdi Amirian,Saeed Shiry Ghidary
# 2                Krzysztof Magiera,Piotr Faliszewski
# 3  Stéphane Airiau,Elise Bonzon,Ulle Endriss,Nico...
# 4  Victor Gutierrez-Basulto,Jean Christoph Jung,C...
#
#                                     doi  email_address  publishing_date  \
# 0  https://doi.org/10.1613/jair.1.11303            NaN              NaN
# 1  https://doi.org/10.1613/jair.1.11322            NaN              NaN
# 2  https://doi.org/10.1613/jair.1.11331            NaN              NaN
# 3     https://doi.org/10.1613/jair.5436            NaN              NaN
# 4     https://doi.org/10.1613/jair.5222            NaN              NaN
#
#            volume     type
# 0  Vol. 66 (2019)  article
# 1  Vol. 66 (2019)  article
# 2  Vol. 66 (2019)  article
# 3  Vol. 60 (2017)  article
# 4  Vol. 58 (2017)  article

# %%
interactions_df = pd.read_csv('bio_latest_clean.csv')
interactions_df.head(10)
# Out:
#                                          affliations  \
# 0  1. Lysosomal Health in Ageing, Hopwood Centre ...
# 1  2. Centre for Cancer Biology, University of So...
# 2  Lysosomal Health in Ageing, Hopwood Centre for...
# 3  School of Biomedical Sciences, Faculty of Medi...
# 4  School of Biomedical Sciences, Faculty of Medi...
# 5  School of Biomedical Sciences, Faculty of Medi...
# 6         UMR 1114 EMMAH, INRA/UAPV, Avignon, France
# 7         UMR 1114 EMMAH, INRA/UAPV, Avignon, France
# 8  1. Curriculum in Genetics and Molecular Biolog...
# 9  2. Department of Biology, UNC Chapel Hill, Cha...
#
#                                         article_name                authors  \
# 0  Subcellular Fractionation of Hela Cells for Ly...       Julian M. Carosi
# 1  Subcellular Fractionation of Hela Cells for Ly...  Kathryn J. Hattersley
# 2  Subcellular Fractionation of Hela Cells for Ly...                Yi  Cui
# 3  Subcellular Fractionation of Hela Cells for Ly...              Zhe  Yang
# 4  Subcellular Fractionation of Hela Cells for Ly...      Rohan D. Teasdale
# 5  Subcellular Fractionation of Hela Cells for Ly...    Timothy J. Sargeant
# 6  Measuring and Imaging the Soil-root-water Syst...         Claude Doussan
# 7  Measuring and Imaging the Soil-root-water Syst...   Emmanuelle Garrigues
# 8  Using indCAPS to Detect CRISPR/Cas9 Induced Mu...       Charles  Hodgens
# 9  Using indCAPS to Detect CRISPR/Cas9 Induced Mu...     Zachary L. Nimchuk
#
#                        doi           email_address  \
# 0  10.21769/BioProtoc.3362
# 1  10.21769/BioProtoc.3362
# 2  10.21769/BioProtoc.3362
# 3  10.21769/BioProtoc.3362
# 4  10.21769/BioProtoc.3362
# 5  10.21769/BioProtoc.3362  TimJSargeant@gmail.com
# 6  10.21769/BioProtoc.3190  claude.doussan@inra.fr
# 7  10.21769/BioProtoc.3190
# 8  10.21769/BioProtoc.3374
# 9  10.21769/BioProtoc.3374
#
#                               volume
# 0  Vol 9, Iss 18, September 20, 2019
# 1  Vol 9, Iss 18, September 20, 2019
# 2  Vol 9, Iss 18, September 20, 2019
# 3  Vol 9, Iss 18, September 20, 2019
# 4  Vol 9, Iss 18, September 20, 2019
# 5  Vol 9, Iss 18, September 20, 2019
# 6       Vol 9, Iss 6, March 20, 2019
# 7       Vol 9, Iss 6, March 20, 2019
# 8  Vol 9, Iss 18, September 20, 2019
# 9  Vol 9, Iss 18, September 20, 2019

# %%
event_type_strength = {
   'VIEW': 1.0,
   'LIKE': 2.0, 
   'BOOKMARK': 2.5, 
   'FOLLOW': 3.0,
   'COMMENT CREATED': 4.0,  
}

interactions_df['eventStrength'] = interactions_df['eventType'].apply(lambda x: event_type_strength[x])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'eventType'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-6-fd06a911cae9> in <module>
#       7 }
#       8
# ----> 9 interactions_df['eventStrength'] = interactions_df['eventType'].apply(lambda x: event_type_strength[x])
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2686             return self._getitem_multilevel(key)
#    2687         else:
# -> 2688             return self._getitem_column(key)
#    2689
#    2690     def _getitem_column(self, key):
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in _getitem_column(self, key)
#    2693         # get column
#    2694         if self.columns.is_unique:
# -> 2695             return self._get_item_cache(key)
#    2696
#    2697         # duplicate columns & possible reduce dimensionality
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in _get_item_cache(self, item)
#    2487         res = cache.get(item)
#    2488         if res is None:
# -> 2489             values = self._data.get(item)
#    2490             res = self._box_item_values(item, values)
#    2491             cache[item] = res
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals.py in get(self, item, fastpath)
#    4113
#    4114             if not isna(item):
# -> 4115                 loc = self.items.get_loc(item)
#    4116             else:
#    4117                 indexer = np.arange(len(self.items))[isna(self.items)]
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
# -> 3080                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    3081
#    3082         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'eventType'
